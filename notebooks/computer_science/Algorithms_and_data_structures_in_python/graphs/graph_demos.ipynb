# %%
import networkx as nx
import matplotlib.pyplot as plt

from graph_adjacency_map import Graph, compute_adjacency_matrix, create_random_graph, plot_graph_via_nx
from dfs_recursive import DfsRecursive
from dfs_iterative import DfsIter

# %config InlineBackend.figure_format='retina'

# %%
g = create_random_graph()

# %%
plot_graph_via_nx(g)

# %% [markdown]
# # 1. Recursive DFS

# %%
dfs = DfsRecursive(g)

# %%
dfs.visited
# Out:
# {<graph_adjacency_map.Graph.Vertex at 0x1080a8e50>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d90>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ee0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f10>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d30>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8370>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8c40>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f70>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8b80>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a82b0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8e20>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fa0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fd0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a85e0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ca0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8220>: False}

# %%
start_node = list(g.vertices())[0]

dfs.dfs(start_node)

# %%
dfs.visited
# Out:
# {<graph_adjacency_map.Graph.Vertex at 0x1080a8e50>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d90>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ee0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f10>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d30>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8370>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8c40>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f70>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8b80>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a82b0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8e20>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fa0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fd0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a85e0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ca0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8220>: True}

# %% [markdown]
# # 2. While loop (with stack) DFS

# %%
dfs = DfsIter(g)

# %%
dfs.visited
# Out:
# {<graph_adjacency_map.Graph.Vertex at 0x1080a8e50>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d90>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ee0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f10>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d30>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8370>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8c40>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f70>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8b80>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a82b0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8e20>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fa0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fd0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a85e0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ca0>: False,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8220>: False}

# %%
dfs.dfs()

# %%
dfs.visited
# Out:
# {<graph_adjacency_map.Graph.Vertex at 0x1080a8e50>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d90>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ee0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f10>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8d30>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8370>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8c40>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8f70>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8b80>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a82b0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8e20>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fa0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8fd0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a85e0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8ca0>: True,
#  <graph_adjacency_map.Graph.Vertex at 0x1080a8220>: True}
