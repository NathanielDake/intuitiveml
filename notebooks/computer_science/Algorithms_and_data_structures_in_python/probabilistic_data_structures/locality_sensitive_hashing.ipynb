# %% [markdown]
# ### Locality Sensitive Hashing

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### Rotation matrix

# %%
def U(deg=30):
    theta = np.radians(deg)
    c, s = np.cos(theta), np.sin(theta)
    U = np.array(((c, -s), (s, c)))
    return U

# %%
np.random.uniform(-5, 5, size=100)
# Out:
# array([ 1.79502484, -0.98585179,  1.36073541, -2.88885126, -4.97948067,
#         4.00133613, -0.91812301, -2.10866018,  4.68739835, -2.91695118,
#         2.04385591, -1.93890346,  2.8640097 , -1.48617523,  0.58113881,
#         1.17777117, -1.95083691,  3.68479927, -3.28659939,  1.22277339,
#         2.5403487 ,  3.94325566, -1.25573511,  1.75884371,  2.58045822,
#        -1.32950418, -4.18285408,  0.62556843,  0.33034639,  3.37523893,
#         3.97886177, -3.32842745,  4.42287726,  3.6039307 ,  0.88982675,
#        -1.23393474, -4.37706639, -1.1067331 , -0.16253204, -2.69709707,
#        -1.55941343,  4.79321091,  3.00393308,  0.47320901,  2.73422118,
#        -3.95487993,  1.86136114,  1.55617305, -1.96956777,  1.33014326,
#        -3.65444742,  3.32264236, -4.2678743 ,  0.43065834, -4.08290366,
#         3.75950523, -1.78200585,  4.5042414 , -0.7564015 ,  1.04479955,
#        -4.24077409,  0.86617371, -4.2190315 ,  0.17960001,  3.50894455,
# ...

# %%
points = np.random.randn(2, 100)
x = points[0]
y = points[1]

# %%
plt.scatter(x,y)

# %%
x_min = -3
x_max = 3
y_min = -3
y_max = 3
interval = 0.5

# %%
cmap = {
    'blue': "#30a2da",
    'yellow': "#fc4f30",
    'red': "#e5ae38"
}

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
plt.figure(figsize=(15, 12), dpi=80)
for gl in grid_lines:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['blue'])

# %% [markdown]
# #### Perform rotation

# %%
U
# Out:
# array([[ 0.8660254, -0.5      ],
#        [ 0.5      ,  0.8660254]])

# %%
glp = grid_lines[0]
vec1 = np.array([glp[0][0], glp[1][0]])
vec2 = np.array([glp[0][1], glp[1][1]])

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []
for gl in grid_lines:
    vec1 = np.array([gl[0][0], gl[1][0]])
    vec2 = np.array([gl[0][1], gl[1][1]])
    
    vec1T = U().dot(vec1)
    vec2T = U().dot(vec2)
    
    grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)
for gl in grid_lines:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['blue'])
    
for gl in grid_lines_transformed:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['red'])

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []
for gl in grid_lines:
    vec1 = np.array([gl[0][0], gl[1][0]])
    vec2 = np.array([gl[0][1], gl[1][1]])
    
    vec1T = U(45).dot(vec1)
    vec2T = U(45).dot(vec2)
    
    grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)
for gl in grid_lines:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['blue'])
    
for gl in grid_lines_transformed:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['red'])

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []
for gl in grid_lines:
    vec1 = np.array([gl[0][0], gl[1][0]])
    vec2 = np.array([gl[0][1], gl[1][1]])
    
    vec1T = U(10).dot(vec1)
    vec2T = U(10).dot(vec2)
    
    grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)
for gl in grid_lines:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['blue'], lw=2)
    
for gl in grid_lines_transformed:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['red'])

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
plt.figure(figsize=(15, 12), dpi=80)
for deg in [10, 30, 70]:
    grid_lines_transformed = []
    for gl in grid_lines:
        vec1 = np.array([gl[0][0], gl[1][0]])
        vec2 = np.array([gl[0][1], gl[1][1]])

        vec1T = U(deg).dot(vec1)
        vec2T = U(deg).dot(vec2)

        grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))



    # for gl in grid_lines:
    #     xs = gl[0]
    #     ys = gl[1]
    #     plt.plot(xs, ys, c=cmap['blue'], lw=2)

    for gl in grid_lines_transformed:
        xs = gl[0]
        ys = gl[1]
        plt.plot(xs, ys, c=cmap['red'])

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []
for gl in grid_lines:
    vec1 = np.array([gl[0][0], gl[1][0]])
    vec2 = np.array([gl[0][1], gl[1][1]])
    
    vec1T = U(10).dot(vec1)
    vec2T = U(10).dot(vec2)
    
    grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)

for gl in grid_lines:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['blue'], lw=1)

pts = [np.array([0.2, 0.3]), np.array([1.2, 2.7])]
for pt in pts:
    plt.scatter(pt[0], pt[1], s=100, c='r', zorder=10)
    
# for gl in grid_lines_transformed:
#     xs = gl[0]
#     ys = gl[1]
#     plt.plot(xs, ys, c=cmap['red'])

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []
for gl in grid_lines:
    vec1 = np.array([gl[0][0], gl[1][0]])
    vec2 = np.array([gl[0][1], gl[1][1]])
    
    vec1T = U(10).dot(vec1)
    vec2T = U(10).dot(vec2)
    
    grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)
    
for gl in grid_lines_transformed:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['red'], lw=1)

pts = [np.array([0.2, 0.3]), np.array([1.2, 2.7])]
for pt in pts:
    ptT = U(10).dot(pt)
    plt.scatter(ptT[0], ptT[1], s=100, c='r', zorder=10)

# %%
U_t = U(-10)
U_t_inv = np.linalg.inv(U_t)

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []

for U_trans in [U_t]:
    for gl in grid_lines:
        vec1 = np.array([gl[0][0], gl[1][0]])
        vec2 = np.array([gl[0][1], gl[1][1]])

        vec1T = U_trans.dot(vec1)
        vec2T = U_trans.dot(vec2)

        grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))

grid_lines_transformed_2 = []
for U_trans in [U_t_inv]:
    for gl in grid_lines_transformed:
        vec1 = np.array([gl[0][0], gl[1][0]])
        vec2 = np.array([gl[0][1], gl[1][1]])

        vec1T = U_trans.dot(vec1)
        vec2T = U_trans.dot(vec2)

        grid_lines_transformed_2.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)
    
for gl in grid_lines_transformed:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['red'], lw=1)
    
for gl in grid_lines_transformed_2:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['blue'], lw=1)

# pts = [np.array([0.2, 0.3]), np.array([1.2, 2.7])]
# for pt in pts:
#     ptT = U(45).dot(pt)
#     print(pt, '---->', ptT)
#     plt.scatter(ptT[0], ptT[1], s=100, c='r', zorder=10)

# %%
grid_lines = []
for x in np.arange(x_min + interval, x_max, interval):
    grid_lines.append(([x, x], [y_min, y_max]))
    
for y in np.arange(y_min + interval, y_max, interval):
    grid_lines.append(([x_min, x_max], [y, y]))
    
grid_lines_transformed = []
for gl in grid_lines:
    vec1 = np.array([gl[0][0], gl[1][0]])
    vec2 = np.array([gl[0][1], gl[1][1]])
    
    vec1T = U(45).dot(vec1)
    vec2T = U(45).dot(vec2)
    
    grid_lines_transformed.append(([vec1T[0], vec2T[0]], [vec1T[1], vec2T[1]]))
    
    
plt.figure(figsize=(15, 12), dpi=80)
    
for gl in grid_lines_transformed:
    xs = gl[0]
    ys = gl[1]
    plt.plot(xs, ys, c=cmap['red'], lw=1)

pts = [np.array([0.2, 0.3]), np.array([1.2, 2.7])]
for pt in pts:
    ptT = U(45).dot(pt)
    print(pt, '---->', ptT)
    plt.scatter(ptT[0], ptT[1], s=100, c='r', zorder=10)
# Out:
# [0.2 0.3] ----> [-0.07071068  0.35355339]
# [1.2 2.7] ----> [-1.06066017  2.75771645]

# %%
", ".join(l)
# Out:
# 'a, b, c'
