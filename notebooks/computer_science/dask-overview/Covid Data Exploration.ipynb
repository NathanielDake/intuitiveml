# %%
import requests
import io 

import pandas as pd

# %% [markdown]
# # 1. Cases by county data
# Found: https://github.com/nytimes/covid-19-data

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv'
r = requests.get(url)

# %%
df = pd.read_csv(io.BytesIO(r.content))

# %%
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %% [markdown]
# #### Notes 1.1
# * https://covidtracking.com/api only had data at state level

# %%
r = requests.get('https://covidtracking.com/api/states/daily.csv')

# %%
df_states = pd.read_csv(io.BytesIO(r.content))

# %%
df_states.columns
# Out:
# Index(['date', 'state', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'hash', 'dateChecked', 'death', 'hospitalized', 'total',
#        'totalTestResults', 'posNeg', 'fips', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %% [markdown]
# #### Notes 1.2
# * JHU data was only at global level. Main link [here](https://console.cloud.google.com/marketplace/details/johnshopkins/covid19_jhu_global_cases?filter=solution-type:dataset&q=covid&id=430e16bb-bd19-42dd-bb7a-d38386a9edf5&_ga=2.240248515.-1701848518.1585755058&pli=1), but can also be found: https://data.humdata.org/dataset/novel-coronavirus-2019-ncov-cases

# %%
r = requests.get('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv')

# %%
df_jhu = pd.read_csv(io.BytesIO(r.content))
df_jhu.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/24/20  3/25/20  3/26/20  3/27/20  \
# 0        0        0        0  ...       74       84       94      110
# 1        0        0        0  ...      123      146      174      186
# 2        0        0        0  ...      264      302      367      409
# 3        0        0        0  ...      164      188      224      267
# 4        0        0        0  ...        3        3        4        4
#
#    3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20
# 0      110      120      170      174     237     273
# 1      197      212      223      243     259     277
# 2      454      511      584      716     847     986
# 3      308      334      370      376     390     428
# 4        5        7        7        7       8       8
#
# [5 rows x 76 columns]

# %% [markdown]
# # 2. Unemployment data
# Info about all of this data: https://download.bls.gov/pub/time.series/la/la.txt

# %%
# %%time
url_county = 'https://download.bls.gov/pub/time.series/la/la.data.64.County'
pd.read_csv(url_county, delim_whitespace=True)
# Out:
# CPU times: user 4.15 s, sys: 1.6 s, total: 5.75 s
# Wall time: 2min 19s
#                     series_id  year period value footnote_codes
# 0        LAUCN010010000000003  1990    M01   6.4            NaN
# 1        LAUCN010010000000003  1990    M02   6.6            NaN
# 2        LAUCN010010000000003  1990    M03   5.8            NaN
# 3        LAUCN010010000000003  1990    M04   6.6            NaN
# 4        LAUCN010010000000003  1990    M05     6            NaN
# ...                       ...   ...    ...   ...            ...
# 5019371  LAUCN721530000000006  2019    M09  9543            NaN
# 5019372  LAUCN721530000000006  2019    M10  9626            NaN
# 5019373  LAUCN721530000000006  2019    M11  9536            NaN
# 5019374  LAUCN721530000000006  2019    M12  9619              P
# 5019375  LAUCN721530000000006  2020    M01  9924              P
#
# [5019376 rows x 5 columns]

# %%
# %%time
url_county = 'https://download.bls.gov/pub/time.series/la/la.data.64.County'
r = requests.get(url_county)
df_county = pd.read_csv(io.BytesIO(r.content), delim_whitespace=True)

df_county = df_county.assign(
    county_id=df_county.series_id.str.slice(start=3, stop=-2)
)
# Out:
# <string>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 4.33 s, sys: 651 ms, total: 4.98 s
# Wall time: 13.9 s

# %%
url_county_map = 'https://download.bls.gov/pub/time.series/la/la.areamaps'

r = requests.get(url_county_map)
df_county_map = pd.read_csv(
    io.BytesIO(r.content),
    delimiter='\t', 
    usecols=['area_code', 'area_text']
)

# %%
df_unemployment_by_county_month = pd.merge(
    df_county,
    df_county_map,
    how='inner',
    left_on='county_id',
    right_on='area_code',
)

# %%
df_unemployment_by_county_month.head()
# Out:
#               series_id  year period value footnote_codes        county_id  \
# 0  LAUCN010010000000003  1990    M01   6.4            NaN  CN0100100000000
# 1  LAUCN010010000000003  1990    M02   6.6            NaN  CN0100100000000
# 2  LAUCN010010000000003  1990    M03   5.8            NaN  CN0100100000000
# 3  LAUCN010010000000003  1990    M04   6.6            NaN  CN0100100000000
# 4  LAUCN010010000000003  1990    M05     6            NaN  CN0100100000000
#
#          area_code           area_text
# 0  CN0100100000000  Autauga County, AL
# 1  CN0100100000000  Autauga County, AL
# 2  CN0100100000000  Autauga County, AL
# 3  CN0100100000000  Autauga County, AL
# 4  CN0100100000000  Autauga County, AL

# %% [markdown]
# #### Notes
# Useful links:
# * https://simplemaps.com/viz/unemployment
# * https://fred.stlouisfed.org/series/TXPECO1URN

# %%
df_unemployment_by_county_month[
    (df_unemployment_by_county_month.year == 2020) &
    (df_unemployment_by_county_month.period == 'M02')
    
]
# Out:
#                    series_id  year period        value footnote_codes  \
# 316343  LAUCN060370000000003  2020    M02          4.5              P
# 316735  LAUCN060370000000004  2020    M02       237327              P
# 317127  LAUCN060370000000005  2020    M02  4.98525e+06              P
# 317519  LAUCN060370000000006  2020    M02  5.22258e+06              P
# 495751  LAUCN110010000000003  2020    M02          5.2              P
# 496143  LAUCN110010000000004  2020    M02        21696              P
# 496535  LAUCN110010000000005  2020    M02       397566              P
# 496927  LAUCN110010000000006  2020    M02       419262              P
# 562839  LAUCN120860000000003  2020    M02          1.5              P
# 563231  LAUCN120860000000004  2020    M02        20378              P
# 563623  LAUCN120860000000005  2020    M02  1.38485e+06              P
# 564015  LAUCN120860000000006  2020    M02  1.40523e+06              P
#
#               county_id        area_code               area_text
# 316343  CN0603700000000  CN0603700000000  Los Angeles County, CA
# 316735  CN0603700000000  CN0603700000000  Los Angeles County, CA
# 317127  CN0603700000000  CN0603700000000  Los Angeles County, CA
# 317519  CN0603700000000  CN0603700000000  Los Angeles County, CA
# 495751  CN1100100000000  CN1100100000000    District of Columbia
# 496143  CN1100100000000  CN1100100000000    District of Columbia
# 496535  CN1100100000000  CN1100100000000    District of Columbia
# 496927  CN1100100000000  CN1100100000000    District of Columbia
# 562839  CN1208600000000  CN1208600000000   Miami-Dade County, FL
# 563231  CN1208600000000  CN1208600000000   Miami-Dade County, FL
# 563623  CN1208600000000  CN1208600000000   Miami-Dade County, FL
# 564015  CN1208600000000  CN1208600000000   Miami-Dade County, FL

# %% [markdown]
# # 3. Stay at home orders

# %%
import sys
sys.path.append('/Users/nathanieldake/.virtualenvs/road-runner-dropbox-download-venv/lib/python3.7/site-packages')

import time 

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

chromeOptions = webdriver.ChromeOptions()
# chromeOptions.headless = True
prefs = {"download.default_directory" : '/Users/nathanieldake/development/unsupervised/customer-projects/covid'}
chromeOptions.add_experimental_option("prefs",prefs)
chromedriver = "path/to/chromedriver.exe"
driver = webdriver.Chrome(ChromeDriverManager().install(), options=chromeOptions)

url = 'https://www.kff.org/health-costs/issue-brief/state-data-and-policy-actions-to-address-coronavirus/'

driver.get(url)
time.sleep(10)

python_accept_terms_button = driver.find_element_by_xpath(
    '//*[@id="hs-eu-confirmation-button"]'
)
python_accept_terms_button.click()

python_export_button = driver.find_element_by_xpath('//*[@id="report-wrapper"]/div/div[2]/div[10]/div[10]/div/div/div/div/div/div/div[1]/div/button[2]')
python_export_button.click()

driver.quit()
# Out:
# Looking for [chromedriver 80.0.3987.106 mac64] driver in cache
# File found in cache by path [/Users/nathanieldake/.wdm/drivers/chromedriver/80.0.3987.106/mac64/chromedriver]

# %%
df_stay_at_home_orders = pd.read_csv('raw_data.csv', skiprows=2)
df_stay_at_home_orders.head()
# Out:
#         Location                                 Stay At Home Order  \
# 0  United States  Statewide (41); High-risk Groups (2); Other (1...
# 1        Alabama                                          Statewide
# 2         Alaska                                          Statewide
# 3        Arizona                                          Statewide
# 4       Arkansas                                                  -
#
#                   Mandatory Quarantine for Travelers  \
# 0  All Travelers (9); All Air Travelers (1); From...
# 1                                                  -
# 2                                      All Travelers
# 3                                                  -
# 4                                                  -
#
#                      Non-Essential Business Closures  \
# 0  All Non-Essential Businesses (35); All Non-Ess...
# 1                       All Non-Essential Businesses
# 2                       All Non-Essential Businesses
# 3                       All Non-Essential Businesses
# 4                                                  -
#
#                                 Large Gatherings Ban  \
# 0  All Gatherings Prohibited (18); >10 Prohibited...
# 1                              >10 People Prohibited
# 2                          All Gatherings Prohibited
# 3                              >10 People Prohibited
# 4                              >10 People Prohibited
#
#      State-Mandated School Closures  \
# 0  Yes (49); Effectively Closed (2)
# 1                               Yes
# 2                               Yes
# 3                               Yes
# 4                               Yes
#
#                                Bar/Restaurant Limits  \
# 0  Closed except for takeout/delivery (47); Limit...
# 1                 Closed except for takeout/delivery
# 2                 Closed except for takeout/delivery
# 3                 Closed except for takeout/delivery
# 4                 Closed except for takeout/delivery
#
#   Primary Election Postponement Emergency Declaration Footnotes
# 0             Yes (13); No (38)      Yes (51); No (0)       NaN
# 1                           Yes                   Yes       NaN
# 2                             -                   Yes       NaN
# 3                             -                   Yes       NaN
# 4                             -                   Yes       NaN

# %% [markdown]
# ## 4. Zip code map

# %%
df_zip_map = pd.read_csv('zip_code_database.csv')

# %%
df_zip_map
# Out:
#          zip      type primary_city acceptable_cities  \
# 0        501    UNIQUE   Holtsville               NaN
# 1        544    UNIQUE   Holtsville               NaN
# 2        601  STANDARD     Adjuntas               NaN
# 3        602  STANDARD       Aguada               NaN
# 4        603  STANDARD    Aguadilla             Ramey
# ...      ...       ...          ...               ...
# 42517  99926    PO BOX   Metlakatla               NaN
# 42518  99927    PO BOX  Point Baker               NaN
# 42519  99928    PO BOX    Ward Cove               NaN
# 42520  99929    PO BOX     Wrangell               NaN
# 42521  99950    PO BOX    Ketchikan  Edna Bay, Kasaan
#
#                                      unacceptable_cities state  \
# 0                                   I R S Service Center    NY
# 1                                     Irs Service Center    NY
# 2      Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3      Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4      Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
# ...                                                  ...   ...
# 42517                                                NaN    AK
# 42518                                                NaN    AK
# 42519                                                NaN    AK
# 42520                                                NaN    AK
# 42521                                                NaN    AK
#
#                                         county             timezone  \
# 0                               Suffolk County     America/New_York
# 1                               Suffolk County     America/New_York
# 2                                     Adjuntas  America/Puerto_Rico
# 3                                          NaN                  NaN
# 4                                    Aguadilla  America/Puerto_Rico
# ...                                        ...                  ...
# 42517  Prince of Wales-Outer Ketchikan Borough       America/Juneau
# 42518  Prince of Wales-Outer Ketchikan Borough       America/Juneau
# 42519                Ketchikan Gateway Borough       America/Juneau
# 42520                         Wrangell Borough                  NaN
# 42521  Prince of Wales-Outer Ketchikan Borough       America/Juneau
#
#       area_codes  latitude  longitude world_region country  decommissioned  \
# 0            631     40.81     -73.04          NaN      US               0
# 1            631     40.81     -73.04          NaN      US               0
# 2        787,939     18.16     -66.72          NaN      US               0
# 3            787     18.38     -67.18          NaN      US               0
# 4            787     18.43     -67.15          NaN      US               0
# ...          ...       ...        ...          ...     ...             ...
# 42517        907     55.14    -131.49          NaN      US               0
# 42518        907     56.30    -133.57          NaN      US               0
# 42519        907     55.45    -131.79          NaN      US               0
# 42520        907     55.95    -131.96          NaN      US               0
# 42521        907     55.34    -131.64          NaN      US               0
#
#        estimated_population          notes
# 0                       384            NaN
# 1                         0            NaN
# 2                         0            NaN
# 3                         0            NaN
# 4                         0            NaN
# ...                     ...            ...
# 42517                  1018            NaN
# 42518                     0            NaN
# 42519                  1281            NaN
# 42520                  1956            NaN
# 42521                     0  no NWS data,
#
# [42522 rows x 16 columns]

# %%
df.county[df.county.str.contains('New Y')]
# Out:
# 416      New York City
# 448      New York City
# 482      New York City
# 518      New York City
# 565      New York City
# 627      New York City
# 715      New York City
# 820      New York City
# 947      New York City
# 1098     New York City
# 1285     New York City
# 1521     New York City
# 1814     New York City
# 2163     New York City
# 2574     New York City
# 3033     New York City
# 3549     New York City
# 4150     New York City
# 4879     New York City
# 5728     New York City
# 6722     New York City
# 7817     New York City
# 9015     New York City
# 10326    New York City
# 11767    New York City
# 13380    New York City
# 15124    New York City
# 16964    New York City
# 18902    New York City
# 20952    New York City
# 23093    New York City
# 25297    New York City
# 27559    New York City
# 29882    New York City
# 32273    New York City
# 34709    New York City
# 37184         New York
# 37185    New York City
# Name: county, dtype: object

# %%
df_zip_map.county.isin(df.county).sum()
# Out:
# 395

# %%
df_zip_map.[df_zip_map.county.str.contains('Boulder').fillna(False)]
# Out:
#          zip      type      primary_city acceptable_cities  \
# 35205  80025    PO BOX  Eldorado Springs     Eldorado Sprg
# 35206  80026  STANDARD         Lafayette               NaN
# 35207  80027  STANDARD        Louisville          Superior
# 35208  80028    UNIQUE        Louisville               NaN
# 35338  80301  STANDARD           Boulder               NaN
# 35339  80302  STANDARD           Boulder               NaN
# 35340  80303  STANDARD           Boulder               NaN
# 35341  80304  STANDARD           Boulder               NaN
# 35342  80305  STANDARD           Boulder               NaN
# 35343  80306    PO BOX           Boulder               NaN
# 35344  80307    PO BOX           Boulder               NaN
# 35345  80308    PO BOX           Boulder               NaN
# 35346  80309    UNIQUE           Boulder               NaN
# 35347  80310    UNIQUE           Boulder               NaN
# 35348  80314    UNIQUE           Boulder               NaN
# 35349  80321    UNIQUE           Boulder               NaN
# 35350  80322    UNIQUE           Boulder               NaN
# 35351  80323    UNIQUE           Boulder               NaN
# 35352  80328    UNIQUE           Boulder               NaN
# 35353  80329    UNIQUE           Boulder               NaN
# 35389  80455  STANDARD         Jamestown               NaN
# 35396  80466  STANDARD         Nederland               NaN
# 35401  80471    PO BOX        Pinecliffe               NaN
# 35410  80481  STANDARD              Ward               NaN
# 35417  80501  STANDARD          Longmont               NaN
# 35418  80502    PO BOX          Longmont               NaN
# 35419  80503  STANDARD          Longmont             Niwot
# 35421  80510  STANDARD        Allenspark               NaN
# 35440  80533    PO BOX           Hygiene               NaN
# 35447  80540  STANDARD             Lyons               NaN
# 35451  80544    PO BOX             Niwot               NaN
#
#               unacceptable_cities state          county        timezone  \
# 35205                         NaN    CO  Boulder County  America/Denver
# 35206                         NaN    CO  Boulder County  America/Denver
# 35207                         NaN    CO  Boulder County  America/Denver
# 35208     Storage Technology Corp    CO  Boulder County  America/Denver
# 35338                         NaN    CO  Boulder County  America/Denver
# 35339                         NaN    CO  Boulder County  America/Denver
# 35340                         NaN    CO  Boulder County  America/Denver
# 35341                         NaN    CO  Boulder County  America/Denver
# 35342                         NaN    CO  Boulder County  America/Denver
# 35343                         NaN    CO  Boulder County  America/Denver
# 35344                         NaN    CO  Boulder County  America/Denver
# 35345                         NaN    CO  Boulder County  America/Denver
# 35346      University Of Colorado    CO  Boulder County  America/Denver
# 35347  Residence Halls Univ Of Co    CO  Boulder County  America/Denver
# 35348                       I B M    CO  Boulder County  America/Denver
# 35349      Neodata Business Reply    CO  Boulder County  America/Denver
# 35350                     Neodata    CO  Boulder County  America/Denver
# 35351                     Neodata    CO  Boulder County  America/Denver
# 35352      Neodata Business Reply    CO  Boulder County  America/Denver
# 35353                     Neodata    CO  Boulder County  America/Denver
# 35389                         NaN    CO  Boulder County  America/Denver
# 35396                         NaN    CO  Boulder County  America/Denver
# 35401                         NaN    CO  Boulder County  America/Denver
# 35410                         NaN    CO  Boulder County  America/Denver
# 35417                         NaN    CO  Boulder County  America/Denver
# 35418                         NaN    CO  Boulder County  America/Denver
# 35419                         NaN    CO  Boulder County  America/Denver
# 35421                         NaN    CO  Boulder County  America/Denver
# 35440                         NaN    CO  Boulder County  America/Denver
# 35447                         NaN    CO  Boulder County  America/Denver
# 35451                         NaN    CO  Boulder County  America/Denver
#
#         area_codes  latitude  longitude world_region country  decommissioned  \
# 35205          303     39.93    -105.27          NaN      US               0
# 35206      720,303     39.99    -105.09          NaN      US               0
# 35207      303,720     39.96    -105.14          NaN      US               0
# 35208          303     39.95    -105.14          NaN      US               1
# 35338      303,720     40.02    -105.25          NaN      US               0
# 35339      303,720     40.02    -105.25          NaN      US               0
# 35340      303,720     40.02    -105.25          NaN      US               0
# 35341      720,303     40.02    -105.25          NaN      US               0
# 35342      303,720     40.02    -105.25          NaN      US               0
# 35343          303     40.02    -105.25          NaN      US               0
# 35344          303     40.02    -105.25          NaN      US               0
# 35345          303     40.02    -105.25          NaN      US               0
# 35346          303     40.02    -105.25          NaN      US               0
# 35347          303     40.02    -105.25          NaN      US               0
# 35348          303     40.02    -105.25          NaN      US               0
# 35349          303     40.02    -105.25          NaN      US               0
# 35350          303     40.02    -105.25          NaN      US               0
# 35351          303     40.02    -105.25          NaN      US               0
# 35352          303     40.02    -105.25          NaN      US               0
# 35353          303     40.02    -105.25          NaN      US               0
# 35389          303     40.11    -105.39          NaN      US               0
# 35396          303     39.96    -105.50          NaN      US               0
# 35401          303     39.93    -105.43          NaN      US               0
# 35410          303     40.07    -105.51          NaN      US               0
# 35417  720,970,303     40.17    -105.11          NaN      US               0
# 35418          303     40.17    -105.11          NaN      US               0
# 35419      720,303     40.17    -105.11          NaN      US               0
# 35421      303,720     40.20    -105.52          NaN      US               0
# 35440          303     40.18    -105.17          NaN      US               0
# 35447          303     40.22    -105.26          NaN      US               0
# 35451          303     40.09    -105.15          NaN      US               0
#
#        estimated_population                             notes
# 35205                     0                               NaN
# 35206                 22364                               NaN
# 35207                 27059                               NaN
# 35208                     0  Converted Decommisioned Zipcodes
# 35338                 19036                               NaN
# 35339                 15073                               NaN
# 35340                 16791                               NaN
# 35341                 21108                               NaN
# 35342                 13065                               NaN
# 35343                  1605                               NaN
# 35344                     0                               NaN
# 35345                  1201                               NaN
# 35346                     0                               NaN
# 35347                     0                               NaN
# 35348                     0                               NaN
# 35349                     0                               NaN
# 35350                     0                               NaN
# 35351                     0                               NaN
# 35352                     0                               NaN
# 35353                     0                               NaN
# 35389                   491                               NaN
# 35396                  3090                               NaN
# 35401                     0                               NaN
# 35410                     0                               NaN
# 35417                 48987                               NaN
# 35418                  1265                               NaN
# 35419                 26346                               NaN
# 35421                     0                               NaN
# 35440                     0                               NaN
# 35447                  4199                               NaN
# 35451                   566                               NaN

# %%
county_clipped = df_zip_map.county.str.split(' ').str[0:-1]

# %%
county_clipped = df_zip_map.county.str.replace(' County', '')

# %%
county_clipped
# Out:
# 0                                        Suffolk
# 1                                        Suffolk
# 2                                       Adjuntas
# 3                                            NaN
# 4                                      Aguadilla
#                           ...
# 42517    Prince of Wales-Outer Ketchikan Borough
# 42518    Prince of Wales-Outer Ketchikan Borough
# 42519                  Ketchikan Gateway Borough
# 42520                           Wrangell Borough
# 42521    Prince of Wales-Outer Ketchikan Borough
# Name: county, Length: 42522, dtype: object

# %%
df.county.isin(county_clipped).sum()
# Out:
# 36227

# %%
df.county[~df.county.isin(county_clipped)]
# Out:
# 416          New York City
# 418                Unknown
# 448          New York City
# 450                Unknown
# 482          New York City
#                ...
# 38041      Waynesboro city
# 38043    Williamsburg city
# 38044      Winchester city
# 38080              Unknown
# 38168            St. Croix
# Name: county, Length: 1970, dtype: object

# %%
df.county.shape
# Out:
# (38197,)

# %%
county_clipped[county_clipped.str.contains('New York').fillna(False)]
# Out:
# Series([], Name: county, dtype: object)

# %%
df_zip_map[df_zip_map.county.str.contains('New York').fillna(False)]
# Out:
#         zip      type primary_city acceptable_cities  \
# 3669  10001  STANDARD     New York               NaN
# 3670  10002  STANDARD     New York     Knickerbocker
# 3671  10003  STANDARD     New York               NaN
# 3672  10004  STANDARD     New York     Bowling Green
# 3673  10005  STANDARD     New York       Wall Street
# ...     ...       ...          ...               ...
# 3829  10281  STANDARD     New York               NaN
# 3830  10282  STANDARD     New York               NaN
# 3831  10285    UNIQUE     New York               NaN
# 3832  10286    UNIQUE     New York               NaN
# 3833  10292    UNIQUE     New York               NaN
#
#                                     unacceptable_cities state  \
# 3669  Empire State, G P O, Greeley Square, Macys Fin...    NY
# 3670         Manhattan, New York City, Ny, Ny City, Nyc    NY
# 3671                                  Cooper, Manhattan    NY
# 3672                                                NaN    NY
# 3673                                     Manhattan, Nyc    NY
# ...                                                 ...   ...
# 3829                                     Manhattan, Nyc    NY
# 3830                                     Manhattan, Nyc    NY
# 3831                          Shearson American Express    NY
# 3832               Bank Of New York, Manhattan, Ny, Nyc    NY
# 3833                        Bache Halsey Stuart Shields    NY
#
#                county          timezone               area_codes  latitude  \
# 3669  New York County  America/New_York  212,718,917,518,646,516     40.71
# 3670  New York County  America/New_York      646,917,212,516,718     40.71
# 3671  New York County  America/New_York      212,646,917,347,718     40.71
# 3672  New York County  America/New_York  212,917,646,516,347,718     40.71
# 3673  New York County  America/New_York      212,646,917,347,718     40.71
# ...               ...               ...                      ...       ...
# 3829  New York County  America/New_York                  212,646     40.71
# 3830  New York County  America/New_York                  212,646     40.71
# 3831  New York County  America/New_York                      212     40.71
# 3832  New York County  America/New_York                      212     40.71
# 3833  New York County  America/New_York                      212     40.71
#
#       longitude world_region country  decommissioned  estimated_population  \
# 3669     -73.99          NaN      US               0                 16553
# 3670     -73.99          NaN      US               0                 70604
# 3671     -73.99          NaN      US               0                 36569
# 3672     -73.99          NaN      US               0                  2909
# 3673     -73.99          NaN      US               0                  6293
# ...         ...          ...     ...             ...                   ...
# 3829     -73.99          NaN      US               0                  2180
# 3830     -73.99          NaN      US               0                  3575
# 3831     -73.99          NaN      US               0                     0
# 3832     -73.99          NaN      US               0                     0
# 3833     -73.99          NaN      US               0                     0
#
#      notes
# 3669   NaN
# 3670   NaN
# 3671   NaN
# 3672   NaN
# 3673   NaN
# ...    ...
# 3829   NaN
# 3830   NaN
# 3831   NaN
# 3832   NaN
# 3833   NaN
#
# [164 rows x 16 columns]

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz (48kB)
#     100% |████████████████████████████████| 51kB 1.3MB/s ta 0:00:01
# Requirement already satisfied: setuptools in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from python-Levenshtein) (39.0.1)
# Building wheels for collected packages: python-Levenshtein
#   Running setup.py bdist_wheel for python-Levenshtein ... done
#   Stored in directory: /Users/nathanieldake/Library/Caches/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-Levenshtein
# tensorboard 2.0.1 has requirement setuptools>=41.0.0, but you'll have setuptools 39.0.1 which is incompatible.
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.0
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import Levenshtein

# %%
Levenshtein.distance('New York', 'New York City')
# Out:
# 5

# %%
df_zip_map.county.dropna().apply(lambda x: Levenshtein.distance(x, 'New York City')).sort_values()
# Out:
# 3747      3
# 3775      3
# 3776      3
# 3777      3
# 3778      3
#          ..
# 42512    34
# 42511    34
# 42510    34
# 42515    34
# 42521    34
# Name: county, Length: 41672, dtype: int64

# %%
idx = df_zip_map.county.dropna().apply(lambda x: Levenshtein.distance(x, 'New York City')).sort_values().index

# %%
df_zip_map.county[idx]
# Out:
# 3747                             New York County
# 3775                             New York County
# 3776                             New York County
# 3777                             New York County
# 3778                             New York County
#                           ...
# 42512    Prince of Wales-Outer Ketchikan Borough
# 42511    Prince of Wales-Outer Ketchikan Borough
# 42510    Prince of Wales-Outer Ketchikan Borough
# 42515    Prince of Wales-Outer Ketchikan Borough
# 42521    Prince of Wales-Outer Ketchikan Borough
# Name: county, Length: 41672, dtype: object

# %% [markdown]
# ## Expansion dataset join class

# %%
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df_zip_map.head()
# Out:
#    zip      type primary_city acceptable_cities  \
# 0  501    UNIQUE   Holtsville               NaN
# 1  544    UNIQUE   Holtsville               NaN
# 2  601  STANDARD     Adjuntas               NaN
# 3  602  STANDARD       Aguada               NaN
# 4  603  STANDARD    Aguadilla             Ramey
#
#                                  unacceptable_cities state          county  \
# 0                               I R S Service Center    NY  Suffolk County
# 1                                 Irs Service Center    NY  Suffolk County
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR        Adjuntas
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR             NaN
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR       Aguadilla
#
#               timezone area_codes  latitude  longitude world_region country  \
# 0     America/New_York        631     40.81     -73.04          NaN      US
# 1     America/New_York        631     40.81     -73.04          NaN      US
# 2  America/Puerto_Rico    787,939     18.16     -66.72          NaN      US
# 3                  NaN        787     18.38     -67.18          NaN      US
# 4  America/Puerto_Rico        787     18.43     -67.15          NaN      US
#
#    decommissioned  estimated_population notes
# 0               0                   384   NaN
# 1               0                     0   NaN
# 2               0                     0   NaN
# 3               0                     0   NaN
# 4               0                     0   NaN

# %%
df = df.ass

# %% [markdown]
# ### Define a preprocess function for each join col

# %%
def preprocess_county(county_col):
    """Lower and remove County from end"""
    return county_col.str.lower().str.replace(' county', '')

# %%
a = preprocess_county(df.county)
b = preprocess_county(df_zip_map.county)
a.isin(b).sum()
# Out:
# 36834

# %%
df = df.assign(
    **{f'processed_county': preprocess_county(df.county)}
)

# %%
df_zip_map = df_zip_map.assign(
    **{f'processed_county': preprocess_county(df_zip_map.county)}
)

# %% [markdown]
# ### Based on preprocessed join col, find closest match

# %%
def closest_match(row, col_map=None):
    sorted_dist_indices = col_map.apply(lambda x: Levenshtein.distance(x, row)).sort_values().index
    return col_map[sorted_dist_indices].iloc[0]

# %%
# 1000 takes 23 seconds
# 2000 takes 47 seconds
# 3000 takes 70 seconds

# After only passing in unique values, down to 6.25 seconds!
# Full set takes 1 min 18 seconds
# Full set takes 3 seconds once calling unique twice!

# %%
# %%time
output = pd.Series(df.processed_county.dropna().unique()).apply(
    closest_match, col_map=pd.Series(df_zip_map.processed_county.unique()).dropna()
)
# Out:
# CPU times: user 3.2 s, sys: 7.99 ms, total: 3.21 s
# Wall time: 3.21 s

# %%
output.shape
# Out:
# (38197,)

# %%
df = df.assign(join_county=output)

# %%
df.head()
# Out:
#          date     county       state     fips  cases  deaths county_processed  \
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0        snohomish
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0        snohomish
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0        snohomish
# 3  2020-01-24       Cook    Illinois  17031.0      1       0             cook
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0        snohomish
#
#   processed_county join_country join_county
# 0        snohomish    snohomish   snohomish
# 1        snohomish    snohomish   snohomish
# 2        snohomish    snohomish   snohomish
# 3             cook         cook        cook
# 4        snohomish    snohomish   snohomish

# %%
df_zip_map.head()
# Out:
#    zip      type primary_city acceptable_cities  \
# 0  501    UNIQUE   Holtsville               NaN
# 1  544    UNIQUE   Holtsville               NaN
# 2  601  STANDARD     Adjuntas               NaN
# 3  602  STANDARD       Aguada               NaN
# 4  603  STANDARD    Aguadilla             Ramey
#
#                                  unacceptable_cities state          county  \
# 0                               I R S Service Center    NY  Suffolk County
# 1                                 Irs Service Center    NY  Suffolk County
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR        Adjuntas
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR             NaN
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR       Aguadilla
#
#               timezone area_codes  latitude  longitude world_region country  \
# 0     America/New_York        631     40.81     -73.04          NaN      US
# 1     America/New_York        631     40.81     -73.04          NaN      US
# 2  America/Puerto_Rico    787,939     18.16     -66.72          NaN      US
# 3                  NaN        787     18.38     -67.18          NaN      US
# 4  America/Puerto_Rico        787     18.43     -67.15          NaN      US
#
#    decommissioned  estimated_population notes county_processed  \
# 0               0                   384   NaN          suffolk
# 1               0                     0   NaN          suffolk
# 2               0                     0   NaN         adjuntas
# 3               0                     0   NaN              NaN
# 4               0                     0   NaN        aguadilla
#
#   processed_county
# 0          suffolk
# 1          suffolk
# 2         adjuntas
# 3              NaN
# 4        aguadilla

# %%
df_zip_map[['zip', 'processed_county']]
# Out:
#          zip                         processed_county
# 0        501                                  suffolk
# 1        544                                  suffolk
# 2        601                                 adjuntas
# 3        602                                      NaN
# 4        603                                aguadilla
# ...      ...                                      ...
# 42517  99926  prince of wales-outer ketchikan borough
# 42518  99927  prince of wales-outer ketchikan borough
# 42519  99928                ketchikan gateway borough
# 42520  99929                         wrangell borough
# 42521  99950  prince of wales-outer ketchikan borough
#
# [42522 rows x 2 columns]

# %%
df_final = pd.merge(
    df,
    df_zip_map[['zip', 'processed_county']],
    how='left',
    left_on='join_county',
    right_on='processed_county'
)

# %%
df_final.shape
# Out:
# (2794472, 12)

# %%
df_final
# Out:
#                date     county       state     fips  cases  deaths  \
# 0        2020-01-21  Snohomish  Washington  53061.0      1       0
# 1        2020-01-21  Snohomish  Washington  53061.0      1       0
# 2        2020-01-21  Snohomish  Washington  53061.0      1       0
# 3        2020-01-21  Snohomish  Washington  53061.0      1       0
# 4        2020-01-21  Snohomish  Washington  53061.0      1       0
# ...             ...        ...         ...      ...    ...     ...
# 2794467  2020-04-06      Uinta     Wyoming  56041.0      3       0
# 2794468  2020-04-06      Uinta     Wyoming  56041.0      3       0
# 2794469  2020-04-06      Uinta     Wyoming  56041.0      3       0
# 2794470  2020-04-06   Washakie     Wyoming  56043.0      4       0
# 2794471  2020-04-06   Washakie     Wyoming  56043.0      4       0
#
#         county_processed processed_county_x join_country join_county    zip  \
# 0              snohomish          snohomish    snohomish   snohomish  98012
# 1              snohomish          snohomish    snohomish   snohomish  98020
# 2              snohomish          snohomish    snohomish   snohomish  98021
# 3              snohomish          snohomish    snohomish   snohomish  98026
# 4              snohomish          snohomish    snohomish   snohomish  98036
# ...                  ...                ...          ...         ...    ...
# 2794467            uinta              uinta        uinta       uinta  82937
# 2794468            uinta              uinta        uinta       uinta  82939
# 2794469            uinta              uinta        uinta       uinta  82944
# 2794470         washakie           washakie     washakie    washakie  82401
# 2794471         washakie           washakie     washakie    washakie  82442
#
#         processed_county_y
# 0                snohomish
# 1                snohomish
# 2                snohomish
# 3                snohomish
# 4                snohomish
# ...                    ...
# 2794467              uinta
# 2794468              uinta
# 2794469              uinta
# 2794470           washakie
# 2794471           washakie
#
# [2794472 rows x 12 columns]

# %%
df_zip_map.shape
# Out:
# (42522, 18)

# %%
df.shape
# Out:
# (38197, 10)

# %%
# The dataset expanded because there were many zip codes that corresponded to a given county!

# %%
# Full thing will take 14 minutes...this could be REALLY bad performance depending on the use case
(df.shape[0] / 1000) * 23 / 60
# Out:
# 14.642183333333334

# %%
df_zip_map.county.dropna()[df_zip_map.county.str.lower().str.contains('cook').dropna()]
# Out:
# 13617     Cook County
# 13623     Cook County
# 13631     Cook County
# 13638     Cook County
# 24356     Cook County
#              ...
# 33320    Cooke County
# 33327    Cooke County
# 33329    Cooke County
# 33336    Cooke County
# 33344    Cooke County
# Name: county, Length: 242, dtype: object

# %%
df_zip_map.processed_county.unique()
# Out:
# array(['suffolk', 'adjuntas', nan, ..., 'ketchikan gateway borough',
#        'prince of wales-outer ketchikan borough', 'wrangell borough'],
#       dtype=object)

# %% [markdown]
# ### Based on preprocessed join col, find closest match (with multiprocessing)

# %%
counties = df.processed_county.dropna()
counties_map = df_zip_map.processed_county.dropna().unique()

# %%
# TODO:
# 1) Split out counties into a number of blocks equal to number of processes, via array_split
# 2) For each block, pass to process (with counties_map)
# 3) In each individual process perform a pandas apply, return lists
# 4) recombine 
# Note: should be 12 times faster than before (not including overhead, so maybe 10xs faster)

# Note: will definitely want to have a way to calculate this mapping via parallelization everytime, since 
# we will be applying more computation than usual

# References
# https://stackoverflow.com/questions/26784164/pandas-multiprocessing-apply
# https://stackoverflow.com/questions/25510482/python-pandas-multiprocessing-apply

# %%
counties.nunique()
# Out:
# 1532

# %%
# Out:
# 12

# %%
import multiprocessing
from multiprocessing import Pool
from functools import partial
import numpy as np

nproc = multiprocessing.cpu_count()

def parallelize(data, func, num_of_processes=8):
    data_split = np.array_split(data, num_of_processes)
    pool = Pool(num_of_processes)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data

def run_on_subset(func, data_subset):
    return data_subset.apply(func, axis=1)

def parallelize_on_rows(data, func, num_of_processes=8):
    return parallelize(data, partial(run_on_subset, func), nproc)

# %%
# %%time
output = df.processed_county.dropna().apply(
    closest_match, col_map=pd.Series(df_zip_map.processed_county.unique()).dropna()
)

# %% [markdown]
# ## Via Dask

# %%
import pandas as pd
import dask.dataframe as dd
from dask.multiprocessing import get
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/array/__init__.py in <module>
#       2     from .blockwise import blockwise, atop
# ----> 3     from .core import (
#       4         Array,
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/array/core.py in <module>
#      22 from . import chunk
# ---> 23 from .. import config, compute
#      24 from ..base import (
#
# ImportError: cannot import name 'compute' from 'dask' (/Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/dataframe/__init__.py in <module>
#       1 try:
# ----> 2     from .core import (
#       3         DataFrame,
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/dataframe/core.py in <module>
#      24
# ---> 25 from .. import array as da
#      26 from .. import core
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/array/__init__.py in <module>
#     249     )
# --> 250     raise ImportError(str(e) + "\n\n" + msg)
#
# ImportError: cannot import name 'compute' from 'dask' (/Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/__init__.py)
#
# Dask array requirements are not installed.
#
# Please either conda or pip install as follows:
#
#   conda install dask                 # either conda install
#   python -m pip install dask[array] --upgrade  # or python -m pip install
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-326-e9616c10cf64> in <module>
#       1 import pandas as pd
# ----> 2 import dask.dataframe as dd
#       3 from dask.multiprocessing import get
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/dask/dataframe/__init__.py in <module>
#      54         "  python -m pip install dask[dataframe] --upgrade  # or python -m pip install"
#      55     )
# ---> 56     raise ImportError(msg) from e
#
# ImportError: Dask dataframe requirements are not installed.
#
# Please either conda or pip install as follows:
#
#   conda install dask                     # either conda install
#   python -m pip install dask[dataframe] --upgrade  # or python -m pip install

# %%
# Leaving off here: 
# https://stackoverflow.com/questions/45545110/how-do-you-parallelize-apply-on-pandas-dataframes-making-use-of-all-cores-on-o

# %%
# !pip install dask[dataframe] --upgrade
# Out:
# Requirement already up-to-date: dask[dataframe] in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (2.14.0)
# Requirement not upgraded as not directly required: pandas>=0.23.0; extra == "dataframe" in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from dask[dataframe]) (0.25.2)
# Requirement not upgraded as not directly required: toolz>=0.8.2; extra == "dataframe" in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from dask[dataframe]) (0.10.0)
# Requirement not upgraded as not directly required: numpy>=1.13.0; extra == "dataframe" in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from dask[dataframe]) (1.17.3)
# Requirement not upgraded as not directly required: fsspec>=0.6.0; extra == "dataframe" in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from dask[dataframe]) (0.7.2)
# Requirement not upgraded as not directly required: partd>=0.3.10; extra == "dataframe" in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from dask[dataframe]) (1.1.0)
# Requirement not upgraded as not directly required: python-dateutil>=2.6.1 in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2.8.0)
# Requirement not upgraded as not directly required: pytz>=2017.2 in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2019.3)
# Requirement not upgraded as not directly required: locket in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from partd>=0.3.10; extra == "dataframe"->dask[dataframe]) (0.2.0)
# Requirement not upgraded as not directly required: six>=1.5 in /Users/nathanieldake/.pyenv/versions/3.7.1/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (1.12.0)
# tensorboard 2.0.1 has requirement setuptools>=41.0.0, but you'll have setuptools 39.0.1 which is incompatible.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ### Ideas for combination of distance metrics
#  * https://pypi.org/project/python-Levenshtein/0.12.0/
#  * https://rawgit.com/ztane/python-Levenshtein/master/docs/Levenshtein.html#Levenshtein-distance
#  * https://towardsdatascience.com/fuzzy-string-matching-in-python-68f240d910fe

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
dist1 = Levenshtein.distance('Cook', 'Cook County')
ratio_1 = fuzz.ratio('Cook', 'Cook County')
print('distance: ', dist1, ' ratio: ', ratio_1)
print('Similarity score: ', ratio_1 / dist1)
# Out:
# distance:  7  ratio:  53
# Similarity score:  7.571428571428571

# %%
dist2 = Levenshtein.distance('Cook', 'Carolina')
ratio_2 = fuzz.ratio('Cook', 'Carolina')
print('distance: ', dist2, ' ratio: ', ratio_2)
print('Similarity score: ', ratio_2 / dist2)
# Out:
# distance:  6  ratio:  33
# Similarity score:  5.5

# %%
dist2 = Levenshtein.distance('Cook', 'Cooke')
ratio_2 = fuzz.ratio('Cook', 'Cooke')
print('distance: ', dist2, ' ratio: ', ratio_2)
print('Similarity score: ', ratio_2 / dist2)
# Out:
# distance:  1  ratio:  89
# Similarity score:  89.0
