# %%
import sys
sys.path.insert(0, '/Users/nathanieldake/.virtualenvs/intuitiveml-venv/lib/python3.7/site-packages')

import requests
import io 

import pandas as pd
import numpy as np
import Levenshtein

# %% [markdown]
# # 1. Cases by county data
# Found: https://github.com/nytimes/covid-19-data

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv'
r = requests.get(url)

# %%
df = pd.read_csv(io.BytesIO(r.content))

# %%
df.sample(5)
# Out:
#              date              county        state     fips  cases  deaths
# 565    2020-03-05       New York City     New York      NaN      4       0
# 6585   2020-03-21             Grenada  Mississippi  28043.0      1       0
# 1441   2020-03-12            Honolulu       Hawaii  15003.0      2       0
# 14383  2020-03-27          Meriwether      Georgia  13199.0      3       0
# 40793  2020-04-08  Petersburg Borough       Alaska   2195.0      1       0

# %%
df.shape
# Out:
# (45881, 6)

# %% [markdown]
# # 2. Zip code map

# %%
df_zip_map = pd.read_csv('zip_code_database.csv')

# %%
df_zip_map.head()
# Out:
#    zip      type primary_city acceptable_cities  \
# 0  501    UNIQUE   Holtsville               NaN
# 1  544    UNIQUE   Holtsville               NaN
# 2  601  STANDARD     Adjuntas               NaN
# 3  602  STANDARD       Aguada               NaN
# 4  603  STANDARD    Aguadilla             Ramey
#
#                                  unacceptable_cities state          county  \
# 0                               I R S Service Center    NY  Suffolk County
# 1                                 Irs Service Center    NY  Suffolk County
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR        Adjuntas
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR             NaN
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR       Aguadilla
#
#               timezone area_codes  latitude  longitude world_region country  \
# 0     America/New_York        631     40.81     -73.04          NaN      US
# 1     America/New_York        631     40.81     -73.04          NaN      US
# 2  America/Puerto_Rico    787,939     18.16     -66.72          NaN      US
# 3                  NaN        787     18.38     -67.18          NaN      US
# 4  America/Puerto_Rico        787     18.43     -67.15          NaN      US
#
#    decommissioned  estimated_population notes
# 0               0                   384   NaN
# 1               0                     0   NaN
# 2               0                     0   NaN
# 3               0                     0   NaN
# 4               0                     0   NaN

# %% [markdown]
# # 3. Expansion dataset join class
# Problem we are trying to solve:
# * How do we map `New York County` to `New York City`?
# * We can perform a simple `.lower()` and drop `County` from all county names, but even then we must be able to map: `new york` to `new york city`.
# * This will clearly be an issue moving forward. Consider, another example, mapping `new york city` to `new york, city`. If we have 100,000 rows it will be nearly impossible to realize there is a random comma that we need to get rid of. No preprocessing will be perfect and allow for us to always have perfect joins.

# %%
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df_zip_map[['zip', 'county']].sample(5)
# Out:
#          zip             county
# 34259  78101       Bexar County
# 18042  41528        Pike County
# 26123  59644  Broadwater County
# 23132  53020   Sheboygan County
# 17681  40384    Woodford County

# %% [markdown]
# ### 3.1 Define a preprocess function for each join col

# %%
def preprocess_county(county_col):
    """Lower and remove County from end"""
    return county_col.str.lower().str.replace(' county', '')

# %%
a = preprocess_county(df.county)
b = preprocess_county(df_zip_map.county)
a.isin(b).sum()
# Out:
# 39284

# %%
df = df.assign(
    **{f'processed_county': preprocess_county(df.county)}
)

# %%
df_zip_map = df_zip_map.assign(
    **{f'processed_county': preprocess_county(df_zip_map.county)}
)

# %% [markdown]
# ### 3.2 Based on preprocessed join col, find closest match (via apply)
# * 1000 takes 23 seconds
# * 2000 takes 47 seconds
# * 3000 takes 70 seconds
#
# * After only passing in unique values, down to 6.25 seconds!
# * Full set takes 1 min 18 seconds
# * Full set takes 3 seconds once calling unique twice!

# %%
def closest_match(row, col_map=None):
    sorted_dist_indices = col_map.apply(lambda x: Levenshtein.distance(x, row)).sort_values().index
    return col_map[sorted_dist_indices].iloc[0]

# %%
# %%time
output = pd.Series(df.processed_county.dropna()).apply(
    closest_match, col_map=pd.Series(df_zip_map.processed_county.unique()).dropna()
)
# Out:
# CPU times: user 1min 27s, sys: 310 ms, total: 1min 28s
# Wall time: 1min 28s

# %% [markdown]
# ### 3.3 Based on preprocessed join col, find closest match (via for loop)

# %%
def closest_match(str_1, str_2):
    return Levenshtein.distance(str_1, str_2)

closest_match_vectorized = np.vectorize(closest_match)

# %%
def create_str_map(col1, col2):
    str_map = {}
    str_array = col2.dropna().unique()
    for x in col1.dropna().unique():
        distances = closest_match_vectorized(x, str_array)
        min_idx = np.argmin(distances)
        str_map[x] = str_array[min_idx]
    return str_map

# %%
# %%time
str_map = create_str_map(df.processed_county, df_zip_map.processed_county)
# Out:
# CPU times: user 1.44 s, sys: 5.84 ms, total: 1.45 s
# Wall time: 1.45 s

# %% [markdown]
# ###  3.4 Apply map

# %%
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df = df.assign(
    join_county=df.processed_county.map(str_map)
)
df.head()
# Out:
#          date     county       state     fips  cases  deaths processed_county  \
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0        snohomish
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0        snohomish
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0        snohomish
# 3  2020-01-24       Cook    Illinois  17031.0      1       0             cook
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0        snohomish
#
#   join_county
# 0   snohomish
# 1   snohomish
# 2   snohomish
# 3        cook
# 4   snohomish

# %% [markdown]
# ### 3.5 Join

# %%
df_final = pd.merge(
    df,
    df_zip_map[['zip', 'processed_county']],
    how='left',
    left_on='join_county',
    right_on='processed_county'
)
print(df_final.shape)
# Out:
# (2973707, 10)

# %% [markdown]
# ---
# # 4. Implement Parallelization
# ### 4.1 Parallelize Finding Closest Match - Basic Python

# %%
counties = df.processed_county
counties_map = df_zip_map.processed_county

# %%
import multiprocessing
from itertools import repeat


def create_str_map_chunked(col1_chunk, col2):
    str_map = {}
    str_array = col2.dropna().unique()
    for x in col1_chunk.dropna().unique():
        distances = closest_match_vectorized(x, str_array)
        min_idx = np.argmin(distances)
        str_map[x] = str_array[min_idx]
    return str_map

nproc = multiprocessing.cpu_count()

data_split = np.array_split(counties, nproc)

# %%
# %%time
with multiprocessing.Pool(multiprocessing.cpu_count()) as pool:
    res = pool.starmap(create_str_map_chunked, zip(data_split, repeat(counties_map)))

# %%
# Out:
# CPU times: user 114 ms, sys: 54.1 ms, total: 168 ms
# Wall time: 2.42 s

# %%
str_map = {k: v for d in res for k, v in d.items()}

# %% [markdown]
# ### 4.2 Parallelize Finding Closest Match - Dask Delayed

# %%
import pandas as pd
import dask.dataframe as dd
from dask.multiprocessing import get
from dask import delayed

# %%
@delayed
def create_str_map_dask(col1_chunk, col2):
    str_map = {}
    str_array = col2.dropna().unique()
    for x in col1_chunk.dropna().unique():
        distances = closest_match_vectorized(x, str_array)
        min_idx = np.argmin(distances)
        str_map[x] = str_array[min_idx]
    return str_map

# %%
results = []
for col1_chunk in np.array_split(counties, nproc):
    results.append(create_str_map_dask(col1_chunk, counties_map))

# %%
# %%time
output = delayed(results).compute()
# Out:
# CPU times: user 13.3 s, sys: 190 ms, total: 13.5 s
# Wall time: 13.3 s

# %%
str_map = {k: v for d in output for k, v in d.items()}

# %%
len(str_map)
# Out:
# 1548

# %%
str_map['cook']
# Out:
# 'cook'

# %%
str_map['new york city']
# Out:
# 'new york'

# %% [markdown]
# ### 4.3 Parallelize Finding Closest Match - Dask Map Partitions

# %%
ddf = dd.from_pandas(df, npartitions=nproc)

# %%
def create_str_map_dask_map_partitions(df, col1, df2=None, col2=None):
    str_map = {}
    
    df_col_arr = df[col1].dropna().unique()
    df2_col_arr = df2[col2].dropna().unique()
    
    for x in df_col_arr:
        distances = closest_match_vectorized(x, df2_col_arr)
        min_idx = np.argmin(distances)
        str_map[x] = df2_col_arr[min_idx]
        
    return str_map

# %%
df_zip_map['processed_county'].dropna().unique()
# Out:
# array(['suffolk', 'adjuntas', 'aguadilla', ...,
#        'ketchikan gateway borough',
#        'prince of wales-outer ketchikan borough', 'wrangell borough'],
#       dtype=object)

# %%
# %%time
output = ddf.map_partitions(
    create_str_map_dask_map_partitions, 
    'processed_county', 
    df2=df_zip_map,
    col2='processed_county'
).compute()
# Out:
# CPU times: user 12.9 s, sys: 184 ms, total: 13.1 s
# Wall time: 13 s

# %%
str_map_2 = {k: v for d in output for k, v in d.items()}

# %%
len(str_map_2)
# Out:
# 1548

# %%
str_map_2['cook']
# Out:
# 'cook'

# %% [markdown]
# # 6. All in Dask

# %%
ddf = dd.from_pandas(df, npartitions=12) # TODO: Don't hard code
ddf_zip_map = dd.from_pandas(df_zip_map, npartitions=12)

# %%
ddf = ddf.assign(
    **{f'processed_county': preprocess_county(ddf.county)}
)
ddf_zip_map = ddf_zip_map.assign(
    **{f'processed_county': preprocess_county(ddf_zip_map.county)}
)

# %%
def create_str_map_dask_map_partitions(df, col1, df2=None, col2=None):
    str_map = {}
    
    df_col_arr = df[col1].dropna().unique()
    df2_col_arr = df2[col2].dropna().unique()
    
    for x in df_col_arr:
        distances = closest_match_vectorized(x, df2_col_arr)
        min_idx = np.argmin(distances)
        str_map[x] = df2_col_arr[min_idx]
        
    return str_map

# %%
col2 = ddf_zip_map.processed_county.compute()

# %%
# %%time
output = ddf.map_partitions(
    create_str_map_dask_map_partitions, 
    'processed_county', 
    df2=df_zip_map,
    col2='processed_county'
).compute()
# Out:
# CPU times: user 13.5 s, sys: 202 ms, total: 13.7 s
# Wall time: 13.6 s

# %%
str_map_3 = {k: v for d in output for k, v in d.items()}

# %%
str_map_3['cook']
# Out:
# 'cook'

# %% [markdown]
# ### Just on series

# %%
def create_str_map_dask_series_map_partitions(col1, col2=None):
    str_map = {}
    
    col1_arr = col1.dropna().unique()
    col2_arr = col2.dropna().unique()
    
    for x in col1_arr:
        distances = closest_match_vectorized(x, col2_arr)
        min_idx = np.argmin(distances)
        str_map[x] = col2_arr[min_idx]
        
    return str_map

# %%
# %%time
output = ddf.processed_county.map_partitions(
    create_str_map_dask_series_map_partitions,
    col2=ddf_zip_map.processed_county.compute()
).compute()
# Out:
# CPU times: user 13.1 s, sys: 181 ms, total: 13.3 s
# Wall time: 13.2 s

# %%
str_map_4 = {k: v for d in output for k, v in d.items()}

# %%
str_map_4
# Out:
# {'snohomish': 'snohomish',
#  'cook': 'cook',
#  'orange': 'orange',
#  'maricopa': 'maricopa',
#  'los angeles': 'los angeles',
#  'santa clara': 'santa clara',
#  'suffolk': 'suffolk',
#  'san francisco': 'san francisco',
#  'dane': 'dane',
#  'san diego': 'san diego',
#  'bexar': 'bexar',
#  'douglas': 'douglas',
#  'humboldt': 'humboldt',
#  'sacramento': 'sacramento',
#  'solano': 'solano',
#  'spokane': 'spokane',
#  'salt lake': 'salt lake',
#  'marin': 'marin',
#  'napa': 'napa',
#  'sonoma': 'sonoma',
#  'washington': 'washington',
#  'king': 'king',
#  'alameda': 'alameda',
#  'hillsborough': 'hillsborough',
#  'manatee': 'manatee',
#  'new york city': 'new york',
#  'unknown': 'union',
#  'placer': 'placer',
#  'san mateo': 'san mateo',
#  'fulton': 'fulton',
#  'norfolk': 'norfolk',
#  'grafton': 'grafton',
#  'walla walla': 'walla walla',
#  'contra costa': 'contra costa',
#  'wake': 'wake',
#  'bergen': 'bergen',
#  'westchester': 'westchester',
#  'fort bend': 'fort bend',
#  'chelan': 'chelan',
#  'jefferson': 'jefferson',
#  'santa rosa': 'santa rosa',
#  'montgomery': 'montgomery',
#  'middlesex': 'middlesex',
#  'clark': 'clark',
#  'washoe': 'washoe',
#  'nassau': 'nassau',
#  'williamson': 'williamson',
#  'harris': 'harris',
#  'pinal': 'pinal',
#  'yolo': 'yolo',
#  'denver': 'denver',
#  'eagle': 'eagle',
#  'el paso': 'el paso',
#  'broward': 'broward',
#  'lee': 'lee',
#  'polk': 'polk',
#  'honolulu': 'honolulu',
#  'marion': 'marion',
#  'fayette': 'fayette',
#  'ramsey': 'ramsey',
#  'camden': 'camden',
#  'rockland': 'rockland',
#  'chatham': 'chatham',
#  'tulsa': 'tulsa',
#  'delaware': 'delaware',
#  'wayne': 'wayne',
#  'charleston': 'charleston',
#  'kershaw': 'kershaw',
#  'davis': 'davis',
#  'pierce': 'pierce',
#  'fresno': 'fresno',
#  'madera': 'madera',
#  'riverside': 'riverside',
#  'santa cruz': 'santa cruz',
#  'district of columbia': 'district of columbia',
#  'charlotte': 'charlotte',
#  'okaloosa': 'okaloosa',
#  'volusia': 'volusia',
#  'cobb': 'cobb',
#  'gwinnett': 'gwinnett',
#  'johnson': 'johnson',
#  'berkshire': 'berkshire',
#  'st. louis': 'st. louis',
#  'rockingham': 'rockingham',
#  'saratoga': 'saratoga',
#  'jackson': 'jackson',
#  'klamath': 'klamath',
#  'bennington': 'bennington',
#  'fairfax': 'fairfax',
#  'kittitas': 'kittitas',
#  'fairfield': 'fairfield',
#  'cherokee': 'cherokee',
#  'hendricks': 'hendricks',
#  'harrison': 'harrison',
#  'harford': 'harford',
#  'worcester': 'worcester',
#  'carver': 'carver',
#  'passaic': 'passaic',
#  'ulster': 'ulster',
#  'spartanburg': 'spartanburg',
#  'davidson': 'davidson',
#  'shelby': 'shelby',
#  'kitsap': 'kitsap',
#  'pima': 'pima',
#  'shasta': 'shasta',
#  'arapahoe': 'arapahoe',
#  'larimer': 'larimer',
#  'dekalb': 'dekalb',
#  'floyd': 'floyd',
#  'noble': 'noble',
#  'pottawattamie': 'pottawattamie',
#  "prince george's": "prince george's",
#  'hudson': 'hudson',
#  'monmouth': 'monmouth',
#  'union': 'union',
#  'cuyahoga': 'cuyahoga',
#  'monroe': 'monroe',
#  'collin': 'collin',
#  'virginia beach city': 'virginia beach city',
#  'san joaquin': 'san joaquin',
#  'ventura': 'ventura',
#  'gunnison': 'gunnison',
#  'alachua': 'alachua',
#  'collier': 'collier',
#  'pasco': 'pasco',
#  'pinellas': 'pinellas',
#  'charlton': 'charlton',
#  'kane': 'kane',
#  'mchenry': 'mchenry',
#  'adams': 'adams',
#  'boone': 'boone',
#  'orleans': 'orleans',
#  'essex': 'essex',
#  'oakland': 'oakland',
#  'anoka': 'anoka',
#  'burlington': 'burlington',
#  'multnomah': 'multnomah',
#  'philadelphia': 'philadelphia',
#  'beadle': 'beadle',
#  'charles mix': 'charles mix',
#  'davison': 'davison',
#  'minnehaha': 'minnehaha',
#  'sullivan': 'sullivan',
#  'dallas': 'dallas',
#  'tarrant': 'tarrant',
#  'weber': 'weber',
#  'loudoun': 'loudoun',
#  'skagit': 'skagit',
#  'whatcom': 'whatcom',
#  'stanislaus': 'stanislaus',
#  'pitkin': 'pitkin',
#  'new castle': 'new castle',
#  'miami-dade': 'miami-dade',
#  'st. johns': 'st. johns',
#  'bartow': 'bartow',
#  'lowndes': 'lowndes',
#  'lake': 'lake',
#  'howard': 'howard',
#  'st. joseph': 'st. joseph',
#  'caddo': 'caddo',
#  'baltimore': 'baltimore',
#  'olmsted': 'olmsted',
#  'forrest': 'forrest',
#  'bernalillo': 'bernalillo',
#  'santa fe': 'santa fe',
#  'socorro': 'socorro',
#  'ward': 'ward',
#  'stark': 'stark',
#  'deschutes': 'deschutes',
#  'linn': 'linn',
#  'umatilla': 'umatilla',
#  'bucks': 'bucks',
#  'lancaster': 'lancaster',
#  'bon homme': 'bon homme',
#  'gregg': 'gregg',
#  'chittenden': 'chittenden',
#  'arlington': 'arlington',
#  'island': 'island',
#  'thurston': 'thurston',
#  'fond du lac': 'fond du lac',
#  'waukesha': 'waukesha',
#  'sheridan': 'sheridan',
#  'anchorage': 'orange',
#  'pulaski': 'pulaski',
#  'tulare': 'tulare',
#  'litchfield': 'litchfield',
#  'clay': 'clay',
#  'duval': 'duval',
#  'palm beach': 'palm beach',
#  'sarasota': 'sarasota',
#  'seminole': 'seminole',
#  'carroll': 'carroll',
#  'wyandotte': 'wyandotte',
#  'androscoggin': 'androscoggin',
#  'ingham': 'ingham',
#  'kent': 'kent',
#  'montcalm': 'montcalm',
#  'st. clair': 'st. clair',
#  'washtenaw': 'washtenaw',
#  'dakota': 'dakota',
#  'hennepin': 'hennepin',
#  'stearns': 'stearns',
#  'greene': 'greene',
#  'cass': 'cass',
#  'carson city': 'carson city',
#  'morris': 'morris',
#  'albany': 'albany',
#  'dutchess': 'dutchess',
#  'herkimer': 'herkimer',
#  'cabarrus': 'cabarrus',
#  'forsyth': 'forsyth',
#  'johnston': 'johnston',
#  'mecklenburg': 'mecklenburg',
#  'onslow': 'onslow',
#  'trumbull': 'trumbull',
#  'clackamas': 'clackamas',
#  'northampton': 'northampton',
#  'pike': 'pike',
#  'knox': 'knox',
#  'alexandria city': 'alexandria city',
#  'hanover': 'hanover',
#  'james city': 'james city',
#  'prince edward': 'prince edward',
#  'prince william': 'prince william',
#  'columbia': 'columbia',
#  'grays harbor': 'grays harbor',
#  'yakima': 'yakima',
#  'elmore': 'elmore',
#  'limestone': 'limestone',
#  'tuscaloosa': 'tuscaloosa',
#  'san benito': 'san benito',
#  'clear creek': 'clear creek',
#  'pueblo': 'pueblo',
#  'routt': 'routt',
#  'summit': 'summit',
#  'weld': 'weld',
#  'osceola': 'osceola',
#  'gordon': 'gordon',
#  'henry': 'henry',
#  'ada': 'ada',
#  'butler': 'butler',
#  'st. charles': 'st. charles',
#  'st. tammany': 'stutsman',
#  'terrebonne': 'terrell',
#  'cumberland': 'cumberland',
#  'anne arundel': 'anne arundel',
#  'charles': 'charles',
#  'bay': 'bay',
#  'charlevoix': 'charlevoix',
#  'leelanau': 'leelanau',
#  'macomb': 'macomb',
#  'wright': 'wright',
#  'copiah': 'copiah',
#  'leflore': 'leflore',
#  'pearl river': 'pearl river',
#  'gallatin': 'gallatin',
#  'lewis and clark': 'lewis and clark',
#  'silver bow': 'silver bow',
#  'yellowstone': 'yellowstone',
#  'ocean': 'ocean',
#  'schenectady': 'schenectady',
#  'oklahoma': 'oklahoma',
#  'chester': 'chester',
#  'mccook': 'mccook',
#  'hamilton': 'hamilton',
#  'rutherford': 'rutherford',
#  'bell': 'bell',
#  'galveston': 'galveston',
#  'smith': 'smith',
#  'travis': 'travis',
#  'harrisonburg city': 'harrisonburg city',
#  'grant': 'grant',
#  'milwaukee': 'milwaukee',
#  'racine': 'racine',
#  'sheboygan': 'sheboygan',
#  'fremont': 'fremont',
#  'baldwin': 'baldwin',
#  'graham': 'graham',
#  'san luis obispo': 'san luis obispo',
#  'boulder': 'boulder',
#  'mesa': 'mesa',
#  'hartford': 'hartford',
#  'new haven': 'new haven',
#  'coweta': 'coweta',
#  'kauai': 'kauai',
#  'blaine': 'blaine',
#  'teton': 'teton',
#  'dupage': 'dupage',
#  'sangamon': 'sangamon',
#  'woodford': 'woodford',
#  'laporte': 'la porte',
#  'wells': 'wells',
#  'franklin': 'franklin',
#  'bourbon': 'bourbon',
#  'nelson': 'nelson',
#  'bossier': 'collier',
#  'lafourche': 'lamoure',
#  'st. john the baptist': 'st. john the baptist parish',
#  'barnstable': 'barnstable',
#  'bristol': 'bristol',
#  'renville': 'renville',
#  'missoula': 'missoula',
#  'mercer': 'mercer',
#  'sandoval': 'sandoval',
#  'broome': 'broome',
#  'tioga': 'tioga',
#  'tompkins': 'tompkins',
#  'brunswick': 'brunswick',
#  'craven': 'craven',
#  'harnett': 'harnett',
#  'belmont': 'belmont',
#  'lorain': 'lorain',
#  'tuscarawas': 'tuscarawas',
#  'allegheny': 'allegheny',
#  'beaufort': 'beaufort',
#  'lexington': 'lexington',
#  'campbell': 'campbell',
#  'brazoria': 'brazoria',
#  'hays': 'hays',
#  'windsor': 'windsor',
#  'chesterfield': 'chesterfield',
#  'spotsylvania': 'spotsylvania',
#  'klickitat': 'klickitat',
#  'winnebago': 'winnebago',
#  'garland': 'garland',
#  'saline': 'saline',
#  'san bernardino': 'san bernardino',
#  'santa barbara': 'santa barbara',
#  'garfield': 'garfield',
#  'baker': 'baker',
#  'citrus': 'citrus',
#  'clarke': 'clarke',
#  'clayton': 'clayton',
#  'dougherty': 'dougherty',
#  'newton': 'newton',
#  'maui': 'maui',
#  'clinton': 'clinton',
#  'whiteside': 'whiteside',
#  'allamakee': 'allamakee',
#  'st. bernard': 'san bernardino',
#  'lincoln': 'lincoln',
#  'baltimore city': 'baltimore city',
#  'hampden': 'hampden',
#  'plymouth': 'plymouth',
#  'ottawa': 'ottawa',
#  'waseca': 'waseca',
#  'hinds': 'hinds',
#  'erie': 'erie',
#  'putnam': 'putnam',
#  'watauga': 'watauga',
#  'wilson': 'wilson',
#  'lucas': 'lucas',
#  'medina': 'medina',
#  'cleveland': 'cleveland',
#  'kay': 'kay',
#  'payne': 'payne',
#  'yamhill': 'yamhill',
#  'lehigh': 'lehigh',
#  'luzerne': 'luzerne',
#  'anderson': 'anderson',
#  'greenville': 'greenville',
#  'horry': 'horry',
#  'denton': 'denton',
#  'utah': 'utah',
#  'lewis': 'lewis',
#  'fairbanks north star borough': 'fairbanks north star borough',
#  'cleburne': 'cleburne',
#  'desha': 'desha',
#  'nevada': 'nevada',
#  'escambia': 'escambia',
#  'hall': 'hall',
#  'paulding': 'paulding',
#  'troup': 'troup',
#  'peoria': 'peoria',
#  'will': 'will',
#  'bartholomew': 'bartholomew',
#  'ascension': 'dickenson',
#  'frederick': 'frederick',
#  'talbot': 'talbot',
#  'benton': 'benton',
#  'blue earth': 'blue earth',
#  'hancock': 'hancock',
#  'hunterdon': 'hunterdon',
#  'somerset': 'somerset',
#  'allegany': 'allegany',
#  'onondaga': 'onondaga',
#  'ontario': 'ontario',
#  'durham': 'durham',
#  'geauga': 'geauga',
#  'canadian': 'canadian',
#  'sevier': 'sevier',
#  'bowie': 'bowie',
#  'matagorda': 'matagorda',
#  'tooele': 'tooele',
#  'wasatch': 'wasatch',
#  'stafford': 'stafford',
#  'york': 'york',
#  'outagamie': 'outagamie',
#  'wood': 'wood',
#  'madison': 'madison',
#  'ketchikan gateway borough': 'ketchikan gateway borough',
#  'navajo': 'navajo',
#  'kern': 'kern',
#  'monterey': 'monterey',
#  'sussex': 'sussex',
#  'brevard': 'brevard',
#  'richmond': 'richmond',
#  'whitfield': 'whitfield',
#  'hawaii': 'hawaii',
#  'adair': 'adair',
#  'black hawk': 'black hawk',
#  'ford': 'ford',
#  'lyon': 'lyon',
#  'east baton rouge': 'east baton rouge parish',
#  'kennebec': 'kennebec',
#  'oxford': 'oxford',
#  'otsego': 'otsego',
#  'martin': 'martin',
#  'nicollet': 'nicollet',
#  'cole': 'cole',
#  'sarpy': 'sarpy',
#  'gloucester': 'gloucester',
#  'warren': 'warren',
#  'taos': 'taos',
#  'rensselaer': 'rensselaer',
#  'wyoming': 'wyoming',
#  'iredell': 'iredell',
#  'sampson': 'sampson',
#  'burleigh': 'burleigh',
#  'coshocton': 'coshocton',
#  'darke': 'darke',
#  'mahoning': 'mahoning',
#  'pawnee': 'pawnee',
#  'lane': 'lane',
#  'beaver': 'beaver',
#  'calhoun': 'calhoun',
#  'richland': 'richland',
#  'brazos': 'brazos',
#  'ellis': 'ellis',
#  'lubbock': 'lubbock',
#  'charlottesville city': 'charlottesville city',
#  'goochland': 'goochland',
#  'henrico': 'henrico',
#  'williamsburg city': 'williamsburg city',
#  'mason': 'mason',
#  'kenosha': 'kenosha',
#  'laramie': 'laramie',
#  'park': 'park',
#  'talladega': 'talladega',
#  'kenai peninsula borough': 'kenai peninsula borough',
#  'coconino': 'coconino',
#  'bradley': 'bradley',
#  'faulkner': 'faulkner',
#  'mendocino': 'mendocino',
#  'yuma': 'yuma',
#  'leon': 'leon',
#  'sumter': 'sumter',
#  'walton': 'walton',
#  'houston': 'houston',
#  'twin falls': 'twin falls',
#  'kankakee': 'kankakee',
#  'kendall': 'kendall',
#  'lasalle': 'la salle',
#  'jennings': 'jennings',
#  'winneshiek': 'winneshiek',
#  'leavenworth': 'leavenworth',
#  'kenton': 'kenton',
#  'penobscot': 'penobscot',
#  'rice': 'rice',
#  'bolivar': 'bolivar',
#  'coahoma': 'coahoma',
#  'desoto': 'desoto',
#  'perry': 'perry',
#  'st. louis city': 'st. louis city',
#  'belknap': 'belknap',
#  'merrimack': 'merrimack',
#  'atlantic': 'atlantic',
#  'chenango': 'chenango',
#  'livingston': 'livingston',
#  'gaston': 'gaston',
#  'guilford': 'guilford',
#  'hoke': 'hoke',
#  'moore': 'moore',
#  'new hanover': 'new hanover',
#  'morton': 'morton',
#  'ashland': 'ashland',
#  'huron': 'huron',
#  'miami': 'miami',
#  'berks': 'berks',
#  'lackawanna': 'lackawanna',
#  'cheatham': 'cheatham',
#  'robertson': 'robertson',
#  'sumner': 'sumner',
#  'lavaca': 'lavaca',
#  'mclennan': 'mclennan',
#  'rusk': 'rusk',
#  'webb': 'webb',
#  'wichita': 'wichita',
#  'box elder': 'box elder',
#  'cache': 'cache',
#  'charles city': 'charles city',
#  'richmond city': 'richmond city',
#  'brown': 'brown',
#  'la crosse': 'la crosse',
#  'chambers': 'chambers',
#  'mobile': 'mobile',
#  'walker': 'walker',
#  'yavapai': 'yavapai',
#  'craighead': 'craighead',
#  'crittenden': 'crittenden',
#  'independence': 'independence',
#  'poinsett': 'poinsett',
#  'pope': 'pope',
#  'searcy': 'searcy',
#  'sebastian': 'sebastian',
#  'van buren': 'van buren',
#  'crowley': 'crowley',
#  'grand': 'grand',
#  'morgan': 'morgan',
#  'tolland': 'tolland',
#  'windham': 'windham',
#  'hernando': 'hernando',
#  'indian river': 'indian river',
#  'bibb': 'bibb',
#  'early': 'early',
#  'effingham': 'effingham',
#  'glynn': 'glynn',
#  'laurens': 'laurens',
#  'peach': 'peach',
#  'rockdale': 'rockdale',
#  'owen': 'owen',
#  'tippecanoe': 'tippecanoe',
#  'dubuque': 'dubuque',
#  'muscatine': 'muscatine',
#  'sedgwick': 'sedgwick',
#  'christian': 'christian',
#  'daviess': 'daviess',
#  'henderson': 'henderson',
#  'scott': 'scott',
#  'assumption': 'sampson',
#  'calcasieu': 'lancaster',
#  'iberia': 'erie',
#  'iberville': 'abbeville',
#  'lafayette': 'lafayette',
#  'plaquemines': 'perquimans',
#  'st. james': 'st. johns',
#  'st. landry': 'st. clair',
#  'webster': 'webster',
#  'west baton rouge': 'west baton rouge parish',
#  'calvert': 'calvert',
#  'wicomico': 'wicomico',
#  'hampshire': 'hampshire',
#  'eaton': 'eaton',
#  'genesee': 'genesee',
#  'midland': 'midland',
#  'mower': 'mower',
#  'holmes': 'holmes',
#  'jones': 'jones',
#  'walthall': 'walthall',
#  'wilkinson': 'wilkinson',
#  'winston': 'winston',
#  'yazoo': 'yazoo',
#  'broadwater': 'broadwater',
#  'flathead': 'flathead',
#  'roosevelt': 'roosevelt',
#  'nemaha': 'nemaha',
#  'elko': 'elko',
#  'cape may': 'cape may',
#  'san miguel': 'san miguel',
#  'schoharie': 'schoharie',
#  'custer': 'custer',
#  'grady': 'grady',
#  'logan': 'logan',
#  'mcclain': 'mcclain',
#  'lebanon': 'lebanon',
#  'westmoreland': 'westmoreland',
#  'abbeville': 'abbeville',
#  'dorchester': 'dorchester',
#  'saluda': 'saluda',
#  'dyer': 'dyer',
#  'cameron': 'cameron',
#  'crane': 'crane',
#  'dewitt': 'de witt',
#  'van zandt': 'van zandt',
#  'clallam': 'clallam',
#  'monongalia': 'monongalia',
#  'tucker': 'tucker',
#  'bayfield': 'bayfield',
#  'calumet': 'calumet',
#  'eau claire': 'eau claire',
#  'ozaukee': 'ozaukee',
#  'sauk': 'sauk',
#  'walworth': 'walworth',
#  'cullman': 'cullman',
#  'lamar': 'lamar',
#  'lauderdale': 'lauderdale',
#  'amador': 'amador',
#  'imperial': 'imperial',
#  'broomfield': 'broomfield',
#  'new london': 'new london',
#  'dawson': 'dawson',
#  'heard': 'heard',
#  'miller': 'miller',
#  'muscogee': 'muscogee',
#  'oconee': 'oconee',
#  'pickens': 'pickens',
#  'randolph': 'randolph',
#  'spalding': 'spalding',
#  'terrell': 'terrell',
#  'tift': 'tift',
#  'turner': 'turner',
#  'worth': 'worth',
#  'bingham': 'bingham',
#  'canyon': 'canyon',
#  'kootenai': 'kootenai',
#  'mclean': 'mclean',
#  'allen': 'allen',
#  'vanderburgh': 'vanderburgh',
#  'vigo': 'vigo',
#  'reno': 'reno',
#  'riley': 'riley',
#  'calloway': 'calloway',
#  'catahoula': 'calhoun',
#  'de soto': 'desoto',
#  'rapides': 'racine',
#  'tangipahoa': 'sagadahoc',
#  'chisago': 'chisago',
#  'fillmore': 'fillmore',
#  'humphreys': 'humphreys',
#  'lawrence': 'lawrence',
#  'marshall': 'marshall',
#  'rankin': 'rankin',
#  'tippah': 'tippah',
#  'dunklin': 'dunklin',
#  'kansas city': 'manassas city',
#  'buffalo': 'buffalo',
#  'nye': 'nye',
#  'cheshire': 'cheshire',
#  'doña ana': 'dona ana',
#  'mckinley': 'mckinley',
#  'niagara': 'niagara',
#  'oneida': 'oneida',
#  'carteret': 'carteret',
#  'pasquotank': 'pasquotank',
#  'pitt': 'pitt',
#  'rowan': 'rowan',
#  'stanly': 'stanly',
#  'ashtabula': 'ashtabula',
#  'columbiana': 'columbiana',
#  'garvin': 'garvin',
#  'centre': 'centre',
#  'potter': 'potter',
#  'aiken': 'aiken',
#  'berkeley': 'berkeley',
#  'clarendon': 'clarendon',
#  'darlington': 'darlington',
#  'florence': 'florence',
#  'orangeburg': 'orangeburg',
#  'blount': 'blount',
#  'dickson': 'dickson',
#  'hamblen': 'hamblen',
#  'maury': 'maury',
#  'tipton': 'tipton',
#  'fannin': 'fannin',
#  'hockley': 'hockley',
#  'upshur': 'upshur',
#  'addison': 'addison',
#  'rutland': 'rutland',
#  'accomack': 'accomack',
#  'newport news city': 'newport news city',
#  'norfolk city': 'norfolk city',
#  'portsmouth city': 'portsmouth city',
#  'cowlitz': 'cowlitz',
#  'san juan': 'san juan',
#  'stevens': 'stevens',
#  'kanawha': 'kanawha',
#  'chippewa': 'chippewa',
#  'dunn': 'dunn',
#  'green': 'green',
#  'marathon': 'marathon',
#  'rock': 'rock',
#  'st. croix': 'st croix',
#  'natrona': 'natrona',
#  'apache': 'apache',
#  'cochise': 'cochise',
#  'butte': 'butte',
#  'el dorado': 'el dorado',
#  'siskiyou': 'siskiyou',
#  'yuba': 'yuba',
#  'chaffee': 'chaffee',
#  'elbert': 'elbert',
#  'hinsdale': 'hinsdale',
#  'montrose': 'montrose',
#  'highlands': 'highlands',
#  'st. lucie': 'st. lucie',
#  'lumpkin': 'lumpkin',
#  'elkhart': 'elkhart',
#  'story': 'story',
#  'spencer': 'spencer',
#  'avoyelles': 'lamoille',
#  'beauregard': 'brevard',
#  'bienville': 'renville',
#  'claiborne': 'claiborne',
#  'evangeline': 'angelina',
#  'ouachita': 'ouachita',
#  'st. mary': "st. mary's",
#  'sagadahoc': 'sagadahoc',
#  'caroline': 'caroline',
#  'nantucket': 'nantucket',
#  'allegan': 'allegan',
#  'barry': 'barry',
#  'berrien': 'berrien',
#  'clare': 'clare',
#  'saginaw': 'saginaw',
#  'tuscola': 'tuscola',
#  'wexford': 'wexford',
#  'dodge': 'dodge',
#  'steele': 'steele',
#  'wabasha': 'wabasha',
#  'attala': 'attala',
#  'george': 'george',
#  'grenada': 'grenada',
#  'itawamba': 'itawamba',
#  'leake': 'leake',
#  'panola': 'panola',
#  'simpson': 'simpson',
#  'tunica': 'tunica',
#  'bates': 'bates',
#  'jasper': 'jasper',
#  'cascade': 'cascade',
#  'ravalli': 'ravalli',
#  'strafford': 'strafford',
#  'lea': 'lea',
#  'steuben': 'steuben',
#  'buncombe': 'buncombe',
#  'catawba': 'catawba',
#  'clermont': 'clermont',
#  'defiance': 'defiance',
#  'licking': 'licking',
#  'josephine': 'josephine',
#  'montour': 'montour',
#  'dillon': 'dillon',
#  'edgefield': 'edgefield',
#  'greenwood': 'greenwood',
#  'marlboro': 'marlboro',
#  'newberry': 'newberry',
#  'cocke': 'cocke',
#  'roane': 'roane',
#  'bastrop': 'bastrop',
#  'castro': 'castro',
#  'deaf smith': 'deaf smith',
#  'oldham': 'oldham',
#  'albemarle': 'albemarle',
#  'botetourt': 'botetourt',
#  'isle of wight': 'isle of wight',
#  'suffolk city': 'suffolk city',
#  'carbon': 'carbon',
#  'bradford': 'bradford',
#  'flagler': 'flagler',
#  'barrow': 'barrow',
#  'butts': 'butts',
#  'chattooga': 'chattooga',
#  'clinch': 'clinch',
#  'coffee': 'coffee',
#  'tattnall': 'tattnall',
#  'twiggs': 'twiggs',
#  'valley': 'valley',
#  'champaign': 'champaign',
#  'jo daviess': 'jo daviess',
#  'rock island': 'rock island',
#  'stephenson': 'stephenson',
#  'ripley': 'ripley',
#  'cerro gordo': 'cerro gordo',
#  'kossuth': 'kossuth',
#  'poweshiek': 'poweshiek',
#  'sioux': 'sioux',
#  'tama': 'tama',
#  'woodbury': 'woodbury',
#  'mitchell': 'mitchell',
#  'breathitt': 'breathitt',
#  'hardin': 'hardin',
#  'jessamine': 'jessamine',
#  'acadia': 'amelia',
#  'cecil': 'cecil',
#  "st. mary's": "st. mary's",
#  'emmet': 'emmet',
#  'gladwin': 'gladwin',
#  'grand traverse': 'grand traverse',
#  'roscommon': 'roscommon',
#  'le sueur': 'le sueur',
#  'chickasaw': 'chickasaw',
#  'oktibbeha': 'oktibbeha',
#  'pontotoc': 'pontotoc',
#  'sunflower': 'sunflower',
#  'tate': 'tate',
#  'salem': 'salem',
#  'cortland': 'cortland',
#  'st. lawrence': 'st. lawrence',
#  'davie': 'davie',
#  'granville': 'granville',
#  'nash': 'nash',
#  'robeson': 'robeson',
#  'scotland': 'scotland',
#  'gallia': 'gallia',
#  'portage': 'portage',
#  'muskogee': 'muskogee',
#  'dauphin': 'dauphin',
#  'schuylkill': 'schuylkill',
#  'colleton': 'colleton',
#  'gibson': 'gibson',
#  'loudon': 'loudon',
#  'mcminn': 'mcminn',
#  'amherst': 'amherst',
#  'bedford': 'bedford',
#  'culpeper': 'culpeper',
#  'fluvanna': 'fluvanna',
#  'louisa': 'louisa',
#  'whitman': 'whitman',
#  'tallapoosa': 'tallapoosa',
#  'juneau city and borough': 'kodiak island borough',
#  'matanuska-susitna borough': 'matanuska-susitna borough',
#  'la plata': 'la plata',
#  'teller': 'teller',
#  'burke': 'burke',
#  'catoosa': 'catoosa',
#  'liberty': 'liberty',
#  'dubois': 'dubois',
#  'wapello': 'wapello',
#  'natchitoches': 'nacogdoches',
#  'st. martin': "st. mary's",
#  'garrett': 'garrett',
#  "queen anne's": "queen anne's",
#  'kalamazoo': 'kalamazoo',
#  'muskegon': 'muskegon',
#  'newaygo': 'newaygo',
#  'big stone': 'big stone',
#  'lac qui parle': 'lac qui parle',
#  'sherburne': 'sherburne',
#  'tallahatchie': 'tallahatchie',
#  'callaway': 'callaway',
#  'moniteau': 'moniteau',
#  'st. francois': 'st francois',
#  'taney': 'taney',
#  'chaves': 'chaves',
#  'cayuga': 'cayuga',
#  'oswego': 'oswego',
#  'alamance': 'alamance',
#  'vance': 'vance',
#  'walsh': 'walsh',
#  'sandusky': 'sandusky',
#  'hood river': 'hood river',
#  'cambria': 'cambria',
#  'georgetown': 'georgetown',
#  'codington': 'codington',
#  'hughes': 'hughes',
#  'lyman': 'lyman',
#  'pennington': 'pennington',
#  'iron': 'iron',
#  'danville city': 'danville city',
#  'rockbridge': 'rockbridge',
#  'autauga': 'autauga',
#  'conway': 'conway',
#  'crawford': 'crawford',
#  'cross': 'cross',
#  'hempstead': 'hempstead',
#  'hot spring': 'hot spring',
#  'stone': 'stone',
#  'white': 'white',
#  'woodruff': 'woodruff',
#  'calaveras': 'calaveras',
#  'merced': 'merced',
#  'mono': 'mono',
#  'delta': 'delta',
#  'huerfano': 'huerfano',
#  'ben hill': 'ben hill',
#  'bryan': 'bryan',
#  'colquitt': 'colquitt',
#  'crisp': 'crisp',
#  'irwin': 'irwin',
#  'macon': 'macon',
#  'meriwether': 'meriwether',
#  'stephens': 'stephens',
#  'telfair': 'telfair',
#  'bannock': 'bannock',
#  'cassia': 'cassia',
#  'grundy': 'grundy',
#  'dearborn': 'dearborn',
#  'decatur': 'decatur',
#  'ohio': 'ohio',
#  'porter': 'porter',
#  'starke': 'starke',
#  'warrick': 'warrick',
#  'buchanan': 'buchanan',
#  'cedar': 'cedar',
#  'doniphan': 'doniphan',
#  'pottawatomie': 'pottawatomie',
#  'woodson': 'woodson',
#  'mccracken': 'mccracken',
#  'menifee': 'menifee',
#  'muhlenberg': 'muhlenberg',
#  'vernon': 'vernon',
#  'waldo': 'waldo',
#  'hillsdale': 'hillsdale',
#  'isabella': 'isabella',
#  'kalkaska': 'kalkaska',
#  'lapeer': 'lapeer',
#  'manistee': 'manistee',
#  'choctaw': 'choctaw',
#  'noxubee': 'noxubee',
#  'cape girardeau': 'cape girardeau',
#  'pemiscot': 'pemiscot',
#  'saunders': 'saunders',
#  'cibola': 'cibola',
#  'curry': 'curry',
#  'chemung': 'chemung',
#  'transylvania': 'transylvania',
#  'highland': 'highland',
#  'mayes': 'mayes',
#  'wagoner': 'wagoner',
#  'clatsop': 'clatsop',
#  'armstrong': 'armstrong',
#  'clearfield': 'clearfield',
#  'juniata': 'juniata',
#  'brookings': 'brookings',
#  'overton': 'overton',
#  'weakley': 'weakley',
#  'comal': 'comal',
#  'falls': 'falls',
#  'grayson': 'grayson',
#  'hidalgo': 'hidalgo',
#  'nueces': 'nueces',
#  'parker': 'parker',
#  'victoria': 'victoria',
#  'caledonia': 'caledonia',
#  'chesapeake city': 'chesapeake city',
#  'halifax': 'halifax',
#  'preston': 'preston',
#  'sweetwater': 'sweetwater',
#  'chilton': 'chilton',
#  'colbert': 'colbert',
#  'etowah': 'etowah',
#  'russell': 'russell',
#  'wilcox': 'wilcox',
#  'drew': 'drew',
#  'inyo': 'inyo',
#  'sutter': 'sutter',
#  'otero': 'otero',
#  'gadsden': 'gadsden',
#  'long': 'long',
#  'taylor': 'taylor',
#  'thomas': 'thomas',
#  'ware': 'ware',
#  'wilkes': 'wilkes',
#  'idaho': 'idaho',
#  'nez perce': 'nez perce',
#  'payette': 'payette',
#  'rush': 'rush',
#  'neosho': 'neosho',
#  'shawnee': 'shawnee',
#  'laurel': 'laurel',
#  'mccreary': 'mccreary',
#  'jefferson davis': 'jefferson davis',
#  'morehouse': 'montrose',
#  'winn': 'linn',
#  'dukes': 'dukes',
#  'iosco': 'iosco',
#  'lenawee': 'lenawee',
#  'luce': 'luce',
#  'marquette': 'marquette',
#  'sanilac': 'sanilac',
#  'goodhue': 'goodhue',
#  'winona': 'winona',
#  'amite': 'amite',
#  'prentiss': 'prentiss',
#  'cooper': 'cooper',
#  'mcdonald': 'mcdonald',
#  'platte': 'platte',
#  'ralls': 'ralls',
#  'hill': 'hill',
#  'eddy': 'eddy',
#  'rio arriba': 'rio arriba',
#  'chautauqua': 'chautauqua',
#  'bertie': 'bertie',
#  'caldwell': 'caldwell',
#  'duplin': 'duplin',
#  'hertford': 'hertford',
#  'lenoir': 'lenoir',
#  'mcdowell': 'mcdowell',
#  'foster': 'foster',
#  'pickaway': 'pickaway',
#  'seneca': 'seneca',
#  'carter': 'carter',
#  'creek': 'creek',
#  'osage': 'osage',
#  'lycoming': 'lycoming',
#  'newport': 'newport',
#  'providence': 'providence',
#  'williamsburg': 'williamsburg',
#  'meade': 'meade',
#  'hawkins': 'hawkins',
#  ...}

# %%
ddf = ddf.assign(
    join_county=ddf.processed_county.map(str_map_4)
)

# %%
ddf_zip_map
# Out:
# Dask DataFrame Structure:
#                   zip    type primary_city acceptable_cities unacceptable_cities   state  county timezone area_codes latitude longitude world_region country decommissioned estimated_population   notes processed_county
# npartitions=12
# 0               int64  object       object            object              object  object  object   object     object  float64   float64       object  object          int64                int64  object           object
# 3544              ...     ...          ...               ...                 ...     ...     ...      ...        ...      ...       ...          ...     ...            ...                  ...     ...              ...
# ...               ...     ...          ...               ...                 ...     ...     ...      ...        ...      ...       ...          ...     ...            ...                  ...     ...              ...
# 38984             ...     ...          ...               ...                 ...     ...     ...      ...        ...      ...       ...          ...     ...            ...                  ...     ...              ...
# 42521             ...     ...          ...               ...                 ...     ...     ...      ...        ...      ...       ...          ...     ...            ...                  ...     ...              ...
# Dask Name: assign, 60 tasks

# %%
# ddf_final = pd.merge(
#     ddf,
#     ddf_zip_map[['zip', 'processed_county']],
#     how='left',
#     left_on='join_county',
#     right_on='processed_county'
# ).compute()
import partd

ddf_final = ddf.merge(
    ddf_zip_map[['zip', 'processed_county']], 
    how='left', 
    left_on='join_county', 
    right_on='processed_county'
).compute()

# %%
ddf_final
# Out:
#               date     county state     fips  cases  deaths  \
# 0       2020-04-03  Salt Lake  Utah  49035.0    541       1
# 1       2020-04-03  Salt Lake  Utah  49035.0    541       1
# 2       2020-04-03  Salt Lake  Utah  49035.0    541       1
# 3       2020-04-03  Salt Lake  Utah  49035.0    541       1
# 4       2020-04-03  Salt Lake  Utah  49035.0    541       1
# ...            ...        ...   ...      ...    ...     ...
# 135060  2020-04-06      Brown  Ohio  39015.0      3       1
# 135061  2020-04-06      Brown  Ohio  39015.0      3       1
# 135062  2020-04-06      Brown  Ohio  39015.0      3       1
# 135063  2020-04-06      Brown  Ohio  39015.0      3       1
# 135064  2020-04-06      Brown  Ohio  39015.0      3       1
#
#        processed_county_x join_county    zip processed_county_y
# 0               salt lake   salt lake  84006          salt lake
# 1               salt lake   salt lake  84020          salt lake
# 2               salt lake   salt lake  84044          salt lake
# 3               salt lake   salt lake  84047          salt lake
# 4               salt lake   salt lake  84065          salt lake
# ...                   ...         ...    ...                ...
# 135060              brown       brown  76804              brown
# 135061              brown       brown  76823              brown
# 135062              brown       brown  76827              brown
# 135063              brown       brown  76857              brown
# 135064              brown       brown  76890              brown
#
# [2973707 rows x 10 columns]

# %% [markdown]
# # Full implementation

# %%
def preprocess_county(county_col):
    """Lower and remove County from end"""
    return county_col.str.lower().str.replace(' county', '')

def preprocess_state(state_col):
    df_state_map = pd.read_csv(
        'https://worldpopulationreview.com/static/states/abbr-name.csv',
        header=None
    ).rename(columns={0: 'abbreviation', 1: 'full'})
    df_state_map = df_state_map[['full', 'abbreviation']]

    df_state_map = df_state_map.assign(
        full=df_state_map.full.str.lower(),
        abbreviation=df_state_map.abbreviation.str.lower()
    )
    
    df_state_dict_map = dict(sorted(df_state_map.values.tolist(), reverse=True))
    state_col = state_col.str.lower().map(df_state_dict_map)

    return state_col


def lower(col):
    return col.str.lower()


def levenshtein_distance(str1, str2):
    return Levenshtein.distance(str1, str2)

# %%
def fuzzy_join(
    left,
    right,
    left_on=(None,),
    right_on=(None,),
    left_preprocess_funcs=(None,),
    right_preprocess_funcs=(None,),
    **kwargs
):
    """
    :param left:
    :param right:
    :param left_on:
    :param right_on:
    :param implementation: In list ['serial', 'multiprocessing', 'dask']
    :return:
    """
    
    # TODO: Add dask (i.e. instantiate dask dataframes)
    
    
    
    # Preprocess each of the join columns
    left = left.assign(**{f'preprocessed_{left_on}': left_preprocess_func(left[left_on])})
    right = right.assign(**{f'preprocessed_{right_on}': right_preprocess_func(right[right_on])})
    
    # Get unique values preprocessed join columns
    left_unique = left[f'preprocessed_{left_on}'].dropna().unique()
    right_unique = right[f'preprocessed_{right_on}'].dropna().unique()

    # Calculate map
    fuzzy_map = fuzzy_match(left_unique, right_unique, **kwargs)
    
    # Apply map to create join column
    left = left.assign(**{f'join_{left_on}': left[f'preprocessed_{left_on}'].map(fuzzy_map)})
    
    # Rename preprocessed col to join col for clarity
    right = right.rename(columns={f'preprocessed_{right_on}': f'join_{right_on}'})
    
    # Perform Join
    df_final = pd.merge(
        left,
        right[['zip', f'join_{right_on}']],
        how='left',
        left_on=f'join_{left_on}',
        right_on=f'join_{right_on}'
    )


    return df_final

# %%
def fuzzy_join(
    left,
    right,
    left_on=[],
    right_on=[],
    **kwargs
):
    """
    :param left:
    :param right:
    :param left_on:
    :param right_on:
    :param implementation: In list ['serial', 'multiprocessing', 'dask']
    :return:
    """
    
    # TODO: Add dask (i.e. instantiate dask dataframes)
    
    assert len(left_on) == len(right_on)
    
    # Preprocess each of the join columns, create joint join column
    
    left_joint_join_col_name = '_'.join([config['col'] for config in left_on])
    preprocessed_left_joint_join_col_name = 'preprocessed_' + left_joint_join_col_name
    left = left.assign(**{preprocessed_left_joint_join_col_name: ''})
    for col_config in left_on:
        preprocessed_col = col_config['preprocess_func'](left[col_config["col"]])
        left = left.assign(
            **{preprocessed_left_joint_join_col_name: left[preprocessed_left_joint_join_col_name] + preprocessed_col + '_'}
        )
        
    right_joint_join_col_name = '_'.join([config['col'] for config in right_on])
    preprocessed_right_joint_join_col_name = 'preprocessed_' + right_joint_join_col_name
    right = right.assign(**{preprocessed_right_joint_join_col_name: ''})
    for col_config in right_on:
        preprocessed_col = col_config['preprocess_func'](right[col_config["col"]])
        right = right.assign(
            **{preprocessed_right_joint_join_col_name: right[preprocessed_right_joint_join_col_name] + preprocessed_col + '_'}
        )
    
    # Get unique values preprocessed join columns
    left_unique = left[preprocessed_left_joint_join_col_name].dropna().unique()
    right_unique = right[preprocessed_right_joint_join_col_name].dropna().unique()
    
    # Calculate map
    fuzzy_map = fuzzy_match(left_unique, right_unique, **kwargs)
    
    # Apply map to create join column
    left = left.assign(
        **{f'join_{left_joint_join_col_name}': left[preprocessed_left_joint_join_col_name].map(fuzzy_map)}
    )
    
    # Rename preprocessed col to join col for clarity
    right = right.rename(columns={preprocessed_right_joint_join_col_name: f'join_{right_joint_join_col_name}'})

    # Perform Join
    df_merged = pd.merge(
        left,
        right,
        how='left',
        left_on=f'join_{left_joint_join_col_name}',
        right_on=f'join_{right_joint_join_col_name}'
    )

    return df_merged

# %%
l, r, df_final = fuzzy_join(
    df,
    df_zip_map,
    left_on=[
        {'col': 'county', 'preprocess_func': preprocess_county},
        {'col': 'state', 'preprocess_func': preprocess_state}
    ],
    right_on=[
        {'col': 'county', 'preprocess_func': preprocess_county},
        {'col': 'state', 'preprocess_func': lower}
    ],
    fuzzy_distance_func=levenshtein_distance,
    implementation='dask',
    num_workers=10
)
# Out:
# hit 10

# %%
import multiprocessing
from itertools import repeat
from dask import delayed

def fuzzy_match(
    map_from,
    map_to,
    fuzzy_distance_func=levenshtein_distance, 
    implementation='serial',
    num_workers=None
):
    
    map_from_arr = pd.Series(map_from).dropna().unique()
    map_to_arr = pd.Series(map_to).dropna().unique()
    
    fuzzy_distance_func_vectorized = np.vectorize(fuzzy_distance_func)
    
    if implementation == 'serial':
        fuzzy_map = {}
        for x in map_from_arr:
            distances = fuzzy_distance_func_vectorized(x, map_to_arr)
            min_idx = np.argmin(distances)
            fuzzy_map[x] = map_to_arr[min_idx]
    
    elif implementation == 'multiprocessing':
        nproc = multiprocessing.cpu_count()
        map_from_arr_split = np.array_split(map_from_arr, nproc)
        
        with multiprocessing.Pool(nproc) as pool:
            results = pool.starmap(
                fuzzy_match_chunked, 
                zip(map_from_arr_split, repeat(map_to_arr), repeat(fuzzy_distance_func_vectorized))
            )
            
        fuzzy_map = {k: v for d in results for k, v in d.items()}
        
    elif implementation == 'dask':
        fuzzy_match_chunked_dask = delayed(fuzzy_match_chunked)

        if num_workers is None:
            num_workers = multiprocessing.cpu_count()
            
        results = []
        for map_from_arr_chunk in np.array_split(map_from_arr, num_workers):
            results.append(
                fuzzy_match_chunked_dask(map_from_arr_chunk, map_to_arr, fuzzy_distance_func_vectorized)
            )
        
        results = delayed(results).compute()
        fuzzy_map = {k: v for d in results for k, v in d.items()}
        
    return fuzzy_map
  

def fuzzy_match_chunked(map_from_arr_chunk, map_to_arr, distance_func):
    fuzzy_map = {}
    for x in map_from_arr_chunk:
        distances = distance_func(x, map_to_arr)
        min_idx = np.argmin(distances)
        fuzzy_map[x] = map_to_arr[min_idx]
    return fuzzy_map

# %%
# %%time
res = fuzzy_match(
    preprocess_county(df.county.dropna()).unique(), 
    preprocess_county(df_zip_map.county.dropna()).unique(),
    implementation='dask',
    num_workers=12
)
# Out:
# hit 12
# CPU times: user 1.49 s, sys: 25.8 ms, total: 1.51 s
# Wall time: 1.5 s

# %%
res
# Out:
# {'snohomish': 'snohomish',
#  'cook': 'cook',
#  'orange': 'orange',
#  'maricopa': 'maricopa',
#  'los angeles': 'los angeles',
#  'santa clara': 'santa clara',
#  'suffolk': 'suffolk',
#  'san francisco': 'san francisco',
#  'dane': 'dane',
#  'san diego': 'san diego',
#  'bexar': 'bexar',
#  'douglas': 'douglas',
#  'humboldt': 'humboldt',
#  'sacramento': 'sacramento',
#  'solano': 'solano',
#  'spokane': 'spokane',
#  'salt lake': 'salt lake',
#  'marin': 'marin',
#  'napa': 'napa',
#  'sonoma': 'sonoma',
#  'washington': 'washington',
#  'king': 'king',
#  'alameda': 'alameda',
#  'hillsborough': 'hillsborough',
#  'manatee': 'manatee',
#  'new york city': 'new york',
#  'unknown': 'union',
#  'placer': 'placer',
#  'san mateo': 'san mateo',
#  'fulton': 'fulton',
#  'norfolk': 'norfolk',
#  'grafton': 'grafton',
#  'walla walla': 'walla walla',
#  'contra costa': 'contra costa',
#  'wake': 'wake',
#  'bergen': 'bergen',
#  'westchester': 'westchester',
#  'fort bend': 'fort bend',
#  'chelan': 'chelan',
#  'jefferson': 'jefferson',
#  'santa rosa': 'santa rosa',
#  'montgomery': 'montgomery',
#  'middlesex': 'middlesex',
#  'clark': 'clark',
#  'washoe': 'washoe',
#  'nassau': 'nassau',
#  'williamson': 'williamson',
#  'harris': 'harris',
#  'pinal': 'pinal',
#  'yolo': 'yolo',
#  'denver': 'denver',
#  'eagle': 'eagle',
#  'el paso': 'el paso',
#  'broward': 'broward',
#  'lee': 'lee',
#  'polk': 'polk',
#  'honolulu': 'honolulu',
#  'marion': 'marion',
#  'fayette': 'fayette',
#  'ramsey': 'ramsey',
#  'camden': 'camden',
#  'rockland': 'rockland',
#  'chatham': 'chatham',
#  'tulsa': 'tulsa',
#  'delaware': 'delaware',
#  'wayne': 'wayne',
#  'charleston': 'charleston',
#  'kershaw': 'kershaw',
#  'davis': 'davis',
#  'pierce': 'pierce',
#  'fresno': 'fresno',
#  'madera': 'madera',
#  'riverside': 'riverside',
#  'santa cruz': 'santa cruz',
#  'district of columbia': 'district of columbia',
#  'charlotte': 'charlotte',
#  'okaloosa': 'okaloosa',
#  'volusia': 'volusia',
#  'cobb': 'cobb',
#  'gwinnett': 'gwinnett',
#  'johnson': 'johnson',
#  'berkshire': 'berkshire',
#  'st. louis': 'st. louis',
#  'rockingham': 'rockingham',
#  'saratoga': 'saratoga',
#  'jackson': 'jackson',
#  'klamath': 'klamath',
#  'bennington': 'bennington',
#  'fairfax': 'fairfax',
#  'kittitas': 'kittitas',
#  'fairfield': 'fairfield',
#  'cherokee': 'cherokee',
#  'hendricks': 'hendricks',
#  'harrison': 'harrison',
#  'harford': 'harford',
#  'worcester': 'worcester',
#  'carver': 'carver',
#  'passaic': 'passaic',
#  'ulster': 'ulster',
#  'spartanburg': 'spartanburg',
#  'davidson': 'davidson',
#  'shelby': 'shelby',
#  'kitsap': 'kitsap',
#  'pima': 'pima',
#  'shasta': 'shasta',
#  'arapahoe': 'arapahoe',
#  'larimer': 'larimer',
#  'dekalb': 'dekalb',
#  'floyd': 'floyd',
#  'noble': 'noble',
#  'pottawattamie': 'pottawattamie',
#  "prince george's": "prince george's",
#  'hudson': 'hudson',
#  'monmouth': 'monmouth',
#  'union': 'union',
#  'cuyahoga': 'cuyahoga',
#  'monroe': 'monroe',
#  'collin': 'collin',
#  'virginia beach city': 'virginia beach city',
#  'san joaquin': 'san joaquin',
#  'ventura': 'ventura',
#  'gunnison': 'gunnison',
#  'alachua': 'alachua',
#  'collier': 'collier',
#  'pasco': 'pasco',
#  'pinellas': 'pinellas',
#  'charlton': 'charlton',
#  'kane': 'kane',
#  'mchenry': 'mchenry',
#  'adams': 'adams',
#  'boone': 'boone',
#  'orleans': 'orleans',
#  'essex': 'essex',
#  'oakland': 'oakland',
#  'anoka': 'anoka',
#  'burlington': 'burlington',
#  'multnomah': 'multnomah',
#  'philadelphia': 'philadelphia',
#  'beadle': 'beadle',
#  'charles mix': 'charles mix',
#  'davison': 'davison',
#  'minnehaha': 'minnehaha',
#  'sullivan': 'sullivan',
#  'dallas': 'dallas',
#  'tarrant': 'tarrant',
#  'weber': 'weber',
#  'loudoun': 'loudoun',
#  'skagit': 'skagit',
#  'whatcom': 'whatcom',
#  'stanislaus': 'stanislaus',
#  'pitkin': 'pitkin',
#  'new castle': 'new castle',
#  'miami-dade': 'miami-dade',
#  'st. johns': 'st. johns',
#  'bartow': 'bartow',
#  'lowndes': 'lowndes',
#  'lake': 'lake',
#  'howard': 'howard',
#  'st. joseph': 'st. joseph',
#  'caddo': 'caddo',
#  'baltimore': 'baltimore',
#  'olmsted': 'olmsted',
#  'forrest': 'forrest',
#  'bernalillo': 'bernalillo',
#  'santa fe': 'santa fe',
#  'socorro': 'socorro',
#  'ward': 'ward',
#  'stark': 'stark',
#  'deschutes': 'deschutes',
#  'linn': 'linn',
#  'umatilla': 'umatilla',
#  'bucks': 'bucks',
#  'lancaster': 'lancaster',
#  'bon homme': 'bon homme',
#  'gregg': 'gregg',
#  'chittenden': 'chittenden',
#  'arlington': 'arlington',
#  'island': 'island',
#  'thurston': 'thurston',
#  'fond du lac': 'fond du lac',
#  'waukesha': 'waukesha',
#  'sheridan': 'sheridan',
#  'anchorage': 'orange',
#  'pulaski': 'pulaski',
#  'tulare': 'tulare',
#  'litchfield': 'litchfield',
#  'clay': 'clay',
#  'duval': 'duval',
#  'palm beach': 'palm beach',
#  'sarasota': 'sarasota',
#  'seminole': 'seminole',
#  'carroll': 'carroll',
#  'wyandotte': 'wyandotte',
#  'androscoggin': 'androscoggin',
#  'ingham': 'ingham',
#  'kent': 'kent',
#  'montcalm': 'montcalm',
#  'st. clair': 'st. clair',
#  'washtenaw': 'washtenaw',
#  'dakota': 'dakota',
#  'hennepin': 'hennepin',
#  'stearns': 'stearns',
#  'greene': 'greene',
#  'cass': 'cass',
#  'carson city': 'carson city',
#  'morris': 'morris',
#  'albany': 'albany',
#  'dutchess': 'dutchess',
#  'herkimer': 'herkimer',
#  'cabarrus': 'cabarrus',
#  'forsyth': 'forsyth',
#  'johnston': 'johnston',
#  'mecklenburg': 'mecklenburg',
#  'onslow': 'onslow',
#  'trumbull': 'trumbull',
#  'clackamas': 'clackamas',
#  'northampton': 'northampton',
#  'pike': 'pike',
#  'knox': 'knox',
#  'alexandria city': 'alexandria city',
#  'hanover': 'hanover',
#  'james city': 'james city',
#  'prince edward': 'prince edward',
#  'prince william': 'prince william',
#  'columbia': 'columbia',
#  'grays harbor': 'grays harbor',
#  'yakima': 'yakima',
#  'elmore': 'elmore',
#  'limestone': 'limestone',
#  'tuscaloosa': 'tuscaloosa',
#  'san benito': 'san benito',
#  'clear creek': 'clear creek',
#  'pueblo': 'pueblo',
#  'routt': 'routt',
#  'summit': 'summit',
#  'weld': 'weld',
#  'osceola': 'osceola',
#  'gordon': 'gordon',
#  'henry': 'henry',
#  'ada': 'ada',
#  'butler': 'butler',
#  'st. charles': 'st. charles',
#  'st. tammany': 'stutsman',
#  'terrebonne': 'terrell',
#  'cumberland': 'cumberland',
#  'anne arundel': 'anne arundel',
#  'charles': 'charles',
#  'bay': 'bay',
#  'charlevoix': 'charlevoix',
#  'leelanau': 'leelanau',
#  'macomb': 'macomb',
#  'wright': 'wright',
#  'copiah': 'copiah',
#  'leflore': 'leflore',
#  'pearl river': 'pearl river',
#  'gallatin': 'gallatin',
#  'lewis and clark': 'lewis and clark',
#  'silver bow': 'silver bow',
#  'yellowstone': 'yellowstone',
#  'ocean': 'ocean',
#  'schenectady': 'schenectady',
#  'oklahoma': 'oklahoma',
#  'chester': 'chester',
#  'mccook': 'mccook',
#  'hamilton': 'hamilton',
#  'rutherford': 'rutherford',
#  'bell': 'bell',
#  'galveston': 'galveston',
#  'smith': 'smith',
#  'travis': 'travis',
#  'harrisonburg city': 'harrisonburg city',
#  'grant': 'grant',
#  'milwaukee': 'milwaukee',
#  'racine': 'racine',
#  'sheboygan': 'sheboygan',
#  'fremont': 'fremont',
#  'baldwin': 'baldwin',
#  'graham': 'graham',
#  'san luis obispo': 'san luis obispo',
#  'boulder': 'boulder',
#  'mesa': 'mesa',
#  'hartford': 'hartford',
#  'new haven': 'new haven',
#  'coweta': 'coweta',
#  'kauai': 'kauai',
#  'blaine': 'blaine',
#  'teton': 'teton',
#  'dupage': 'dupage',
#  'sangamon': 'sangamon',
#  'woodford': 'woodford',
#  'laporte': 'la porte',
#  'wells': 'wells',
#  'franklin': 'franklin',
#  'bourbon': 'bourbon',
#  'nelson': 'nelson',
#  'bossier': 'collier',
#  'lafourche': 'lamoure',
#  'st. john the baptist': 'st. john the baptist parish',
#  'barnstable': 'barnstable',
#  'bristol': 'bristol',
#  'renville': 'renville',
#  'missoula': 'missoula',
#  'mercer': 'mercer',
#  'sandoval': 'sandoval',
#  'broome': 'broome',
#  'tioga': 'tioga',
#  'tompkins': 'tompkins',
#  'brunswick': 'brunswick',
#  'craven': 'craven',
#  'harnett': 'harnett',
#  'belmont': 'belmont',
#  'lorain': 'lorain',
#  'tuscarawas': 'tuscarawas',
#  'allegheny': 'allegheny',
#  'beaufort': 'beaufort',
#  'lexington': 'lexington',
#  'campbell': 'campbell',
#  'brazoria': 'brazoria',
#  'hays': 'hays',
#  'windsor': 'windsor',
#  'chesterfield': 'chesterfield',
#  'spotsylvania': 'spotsylvania',
#  'klickitat': 'klickitat',
#  'winnebago': 'winnebago',
#  'garland': 'garland',
#  'saline': 'saline',
#  'san bernardino': 'san bernardino',
#  'santa barbara': 'santa barbara',
#  'garfield': 'garfield',
#  'baker': 'baker',
#  'citrus': 'citrus',
#  'clarke': 'clarke',
#  'clayton': 'clayton',
#  'dougherty': 'dougherty',
#  'newton': 'newton',
#  'maui': 'maui',
#  'clinton': 'clinton',
#  'whiteside': 'whiteside',
#  'allamakee': 'allamakee',
#  'st. bernard': 'san bernardino',
#  'lincoln': 'lincoln',
#  'baltimore city': 'baltimore city',
#  'hampden': 'hampden',
#  'plymouth': 'plymouth',
#  'ottawa': 'ottawa',
#  'waseca': 'waseca',
#  'hinds': 'hinds',
#  'erie': 'erie',
#  'putnam': 'putnam',
#  'watauga': 'watauga',
#  'wilson': 'wilson',
#  'lucas': 'lucas',
#  'medina': 'medina',
#  'cleveland': 'cleveland',
#  'kay': 'kay',
#  'payne': 'payne',
#  'yamhill': 'yamhill',
#  'lehigh': 'lehigh',
#  'luzerne': 'luzerne',
#  'anderson': 'anderson',
#  'greenville': 'greenville',
#  'horry': 'horry',
#  'denton': 'denton',
#  'utah': 'utah',
#  'lewis': 'lewis',
#  'fairbanks north star borough': 'fairbanks north star borough',
#  'cleburne': 'cleburne',
#  'desha': 'desha',
#  'nevada': 'nevada',
#  'escambia': 'escambia',
#  'hall': 'hall',
#  'paulding': 'paulding',
#  'troup': 'troup',
#  'peoria': 'peoria',
#  'will': 'will',
#  'bartholomew': 'bartholomew',
#  'ascension': 'dickenson',
#  'frederick': 'frederick',
#  'talbot': 'talbot',
#  'benton': 'benton',
#  'blue earth': 'blue earth',
#  'hancock': 'hancock',
#  'hunterdon': 'hunterdon',
#  'somerset': 'somerset',
#  'allegany': 'allegany',
#  'onondaga': 'onondaga',
#  'ontario': 'ontario',
#  'durham': 'durham',
#  'geauga': 'geauga',
#  'canadian': 'canadian',
#  'sevier': 'sevier',
#  'bowie': 'bowie',
#  'matagorda': 'matagorda',
#  'tooele': 'tooele',
#  'wasatch': 'wasatch',
#  'stafford': 'stafford',
#  'york': 'york',
#  'outagamie': 'outagamie',
#  'wood': 'wood',
#  'madison': 'madison',
#  'ketchikan gateway borough': 'ketchikan gateway borough',
#  'navajo': 'navajo',
#  'kern': 'kern',
#  'monterey': 'monterey',
#  'sussex': 'sussex',
#  'brevard': 'brevard',
#  'richmond': 'richmond',
#  'whitfield': 'whitfield',
#  'hawaii': 'hawaii',
#  'adair': 'adair',
#  'black hawk': 'black hawk',
#  'ford': 'ford',
#  'lyon': 'lyon',
#  'east baton rouge': 'east baton rouge parish',
#  'kennebec': 'kennebec',
#  'oxford': 'oxford',
#  'otsego': 'otsego',
#  'martin': 'martin',
#  'nicollet': 'nicollet',
#  'cole': 'cole',
#  'sarpy': 'sarpy',
#  'gloucester': 'gloucester',
#  'warren': 'warren',
#  'taos': 'taos',
#  'rensselaer': 'rensselaer',
#  'wyoming': 'wyoming',
#  'iredell': 'iredell',
#  'sampson': 'sampson',
#  'burleigh': 'burleigh',
#  'coshocton': 'coshocton',
#  'darke': 'darke',
#  'mahoning': 'mahoning',
#  'pawnee': 'pawnee',
#  'lane': 'lane',
#  'beaver': 'beaver',
#  'calhoun': 'calhoun',
#  'richland': 'richland',
#  'brazos': 'brazos',
#  'ellis': 'ellis',
#  'lubbock': 'lubbock',
#  'charlottesville city': 'charlottesville city',
#  'goochland': 'goochland',
#  'henrico': 'henrico',
#  'williamsburg city': 'williamsburg city',
#  'mason': 'mason',
#  'kenosha': 'kenosha',
#  'laramie': 'laramie',
#  'park': 'park',
#  'talladega': 'talladega',
#  'kenai peninsula borough': 'kenai peninsula borough',
#  'coconino': 'coconino',
#  'bradley': 'bradley',
#  'faulkner': 'faulkner',
#  'mendocino': 'mendocino',
#  'yuma': 'yuma',
#  'leon': 'leon',
#  'sumter': 'sumter',
#  'walton': 'walton',
#  'houston': 'houston',
#  'twin falls': 'twin falls',
#  'kankakee': 'kankakee',
#  'kendall': 'kendall',
#  'lasalle': 'la salle',
#  'jennings': 'jennings',
#  'winneshiek': 'winneshiek',
#  'leavenworth': 'leavenworth',
#  'kenton': 'kenton',
#  'penobscot': 'penobscot',
#  'rice': 'rice',
#  'bolivar': 'bolivar',
#  'coahoma': 'coahoma',
#  'desoto': 'desoto',
#  'perry': 'perry',
#  'st. louis city': 'st. louis city',
#  'belknap': 'belknap',
#  'merrimack': 'merrimack',
#  'atlantic': 'atlantic',
#  'chenango': 'chenango',
#  'livingston': 'livingston',
#  'gaston': 'gaston',
#  'guilford': 'guilford',
#  'hoke': 'hoke',
#  'moore': 'moore',
#  'new hanover': 'new hanover',
#  'morton': 'morton',
#  'ashland': 'ashland',
#  'huron': 'huron',
#  'miami': 'miami',
#  'berks': 'berks',
#  'lackawanna': 'lackawanna',
#  'cheatham': 'cheatham',
#  'robertson': 'robertson',
#  'sumner': 'sumner',
#  'lavaca': 'lavaca',
#  'mclennan': 'mclennan',
#  'rusk': 'rusk',
#  'webb': 'webb',
#  'wichita': 'wichita',
#  'box elder': 'box elder',
#  'cache': 'cache',
#  'charles city': 'charles city',
#  'richmond city': 'richmond city',
#  'brown': 'brown',
#  'la crosse': 'la crosse',
#  'chambers': 'chambers',
#  'mobile': 'mobile',
#  'walker': 'walker',
#  'yavapai': 'yavapai',
#  'craighead': 'craighead',
#  'crittenden': 'crittenden',
#  'independence': 'independence',
#  'poinsett': 'poinsett',
#  'pope': 'pope',
#  'searcy': 'searcy',
#  'sebastian': 'sebastian',
#  'van buren': 'van buren',
#  'crowley': 'crowley',
#  'grand': 'grand',
#  'morgan': 'morgan',
#  'tolland': 'tolland',
#  'windham': 'windham',
#  'hernando': 'hernando',
#  'indian river': 'indian river',
#  'bibb': 'bibb',
#  'early': 'early',
#  'effingham': 'effingham',
#  'glynn': 'glynn',
#  'laurens': 'laurens',
#  'peach': 'peach',
#  'rockdale': 'rockdale',
#  'owen': 'owen',
#  'tippecanoe': 'tippecanoe',
#  'dubuque': 'dubuque',
#  'muscatine': 'muscatine',
#  'sedgwick': 'sedgwick',
#  'christian': 'christian',
#  'daviess': 'daviess',
#  'henderson': 'henderson',
#  'scott': 'scott',
#  'assumption': 'sampson',
#  'calcasieu': 'lancaster',
#  'iberia': 'erie',
#  'iberville': 'abbeville',
#  'lafayette': 'lafayette',
#  'plaquemines': 'perquimans',
#  'st. james': 'st. johns',
#  'st. landry': 'st. clair',
#  'webster': 'webster',
#  'west baton rouge': 'west baton rouge parish',
#  'calvert': 'calvert',
#  'wicomico': 'wicomico',
#  'hampshire': 'hampshire',
#  'eaton': 'eaton',
#  'genesee': 'genesee',
#  'midland': 'midland',
#  'mower': 'mower',
#  'holmes': 'holmes',
#  'jones': 'jones',
#  'walthall': 'walthall',
#  'wilkinson': 'wilkinson',
#  'winston': 'winston',
#  'yazoo': 'yazoo',
#  'broadwater': 'broadwater',
#  'flathead': 'flathead',
#  'roosevelt': 'roosevelt',
#  'nemaha': 'nemaha',
#  'elko': 'elko',
#  'cape may': 'cape may',
#  'san miguel': 'san miguel',
#  'schoharie': 'schoharie',
#  'custer': 'custer',
#  'grady': 'grady',
#  'logan': 'logan',
#  'mcclain': 'mcclain',
#  'lebanon': 'lebanon',
#  'westmoreland': 'westmoreland',
#  'abbeville': 'abbeville',
#  'dorchester': 'dorchester',
#  'saluda': 'saluda',
#  'dyer': 'dyer',
#  'cameron': 'cameron',
#  'crane': 'crane',
#  'dewitt': 'de witt',
#  'van zandt': 'van zandt',
#  'clallam': 'clallam',
#  'monongalia': 'monongalia',
#  'tucker': 'tucker',
#  'bayfield': 'bayfield',
#  'calumet': 'calumet',
#  'eau claire': 'eau claire',
#  'ozaukee': 'ozaukee',
#  'sauk': 'sauk',
#  'walworth': 'walworth',
#  'cullman': 'cullman',
#  'lamar': 'lamar',
#  'lauderdale': 'lauderdale',
#  'amador': 'amador',
#  'imperial': 'imperial',
#  'broomfield': 'broomfield',
#  'new london': 'new london',
#  'dawson': 'dawson',
#  'heard': 'heard',
#  'miller': 'miller',
#  'muscogee': 'muscogee',
#  'oconee': 'oconee',
#  'pickens': 'pickens',
#  'randolph': 'randolph',
#  'spalding': 'spalding',
#  'terrell': 'terrell',
#  'tift': 'tift',
#  'turner': 'turner',
#  'worth': 'worth',
#  'bingham': 'bingham',
#  'canyon': 'canyon',
#  'kootenai': 'kootenai',
#  'mclean': 'mclean',
#  'allen': 'allen',
#  'vanderburgh': 'vanderburgh',
#  'vigo': 'vigo',
#  'reno': 'reno',
#  'riley': 'riley',
#  'calloway': 'calloway',
#  'catahoula': 'calhoun',
#  'de soto': 'desoto',
#  'rapides': 'racine',
#  'tangipahoa': 'sagadahoc',
#  'chisago': 'chisago',
#  'fillmore': 'fillmore',
#  'humphreys': 'humphreys',
#  'lawrence': 'lawrence',
#  'marshall': 'marshall',
#  'rankin': 'rankin',
#  'tippah': 'tippah',
#  'dunklin': 'dunklin',
#  'kansas city': 'manassas city',
#  'buffalo': 'buffalo',
#  'nye': 'nye',
#  'cheshire': 'cheshire',
#  'doña ana': 'dona ana',
#  'mckinley': 'mckinley',
#  'niagara': 'niagara',
#  'oneida': 'oneida',
#  'carteret': 'carteret',
#  'pasquotank': 'pasquotank',
#  'pitt': 'pitt',
#  'rowan': 'rowan',
#  'stanly': 'stanly',
#  'ashtabula': 'ashtabula',
#  'columbiana': 'columbiana',
#  'garvin': 'garvin',
#  'centre': 'centre',
#  'potter': 'potter',
#  'aiken': 'aiken',
#  'berkeley': 'berkeley',
#  'clarendon': 'clarendon',
#  'darlington': 'darlington',
#  'florence': 'florence',
#  'orangeburg': 'orangeburg',
#  'blount': 'blount',
#  'dickson': 'dickson',
#  'hamblen': 'hamblen',
#  'maury': 'maury',
#  'tipton': 'tipton',
#  'fannin': 'fannin',
#  'hockley': 'hockley',
#  'upshur': 'upshur',
#  'addison': 'addison',
#  'rutland': 'rutland',
#  'accomack': 'accomack',
#  'newport news city': 'newport news city',
#  'norfolk city': 'norfolk city',
#  'portsmouth city': 'portsmouth city',
#  'cowlitz': 'cowlitz',
#  'san juan': 'san juan',
#  'stevens': 'stevens',
#  'kanawha': 'kanawha',
#  'chippewa': 'chippewa',
#  'dunn': 'dunn',
#  'green': 'green',
#  'marathon': 'marathon',
#  'rock': 'rock',
#  'st. croix': 'st croix',
#  'natrona': 'natrona',
#  'apache': 'apache',
#  'cochise': 'cochise',
#  'butte': 'butte',
#  'el dorado': 'el dorado',
#  'siskiyou': 'siskiyou',
#  'yuba': 'yuba',
#  'chaffee': 'chaffee',
#  'elbert': 'elbert',
#  'hinsdale': 'hinsdale',
#  'montrose': 'montrose',
#  'highlands': 'highlands',
#  'st. lucie': 'st. lucie',
#  'lumpkin': 'lumpkin',
#  'elkhart': 'elkhart',
#  'story': 'story',
#  'spencer': 'spencer',
#  'avoyelles': 'lamoille',
#  'beauregard': 'brevard',
#  'bienville': 'renville',
#  'claiborne': 'claiborne',
#  'evangeline': 'angelina',
#  'ouachita': 'ouachita',
#  'st. mary': "st. mary's",
#  'sagadahoc': 'sagadahoc',
#  'caroline': 'caroline',
#  'nantucket': 'nantucket',
#  'allegan': 'allegan',
#  'barry': 'barry',
#  'berrien': 'berrien',
#  'clare': 'clare',
#  'saginaw': 'saginaw',
#  'tuscola': 'tuscola',
#  'wexford': 'wexford',
#  'dodge': 'dodge',
#  'steele': 'steele',
#  'wabasha': 'wabasha',
#  'attala': 'attala',
#  'george': 'george',
#  'grenada': 'grenada',
#  'itawamba': 'itawamba',
#  'leake': 'leake',
#  'panola': 'panola',
#  'simpson': 'simpson',
#  'tunica': 'tunica',
#  'bates': 'bates',
#  'jasper': 'jasper',
#  'cascade': 'cascade',
#  'ravalli': 'ravalli',
#  'strafford': 'strafford',
#  'lea': 'lea',
#  'steuben': 'steuben',
#  'buncombe': 'buncombe',
#  'catawba': 'catawba',
#  'clermont': 'clermont',
#  'defiance': 'defiance',
#  'licking': 'licking',
#  'josephine': 'josephine',
#  'montour': 'montour',
#  'dillon': 'dillon',
#  'edgefield': 'edgefield',
#  'greenwood': 'greenwood',
#  'marlboro': 'marlboro',
#  'newberry': 'newberry',
#  'cocke': 'cocke',
#  'roane': 'roane',
#  'bastrop': 'bastrop',
#  'castro': 'castro',
#  'deaf smith': 'deaf smith',
#  'oldham': 'oldham',
#  'albemarle': 'albemarle',
#  'botetourt': 'botetourt',
#  'isle of wight': 'isle of wight',
#  'suffolk city': 'suffolk city',
#  'carbon': 'carbon',
#  'bradford': 'bradford',
#  'flagler': 'flagler',
#  'barrow': 'barrow',
#  'butts': 'butts',
#  'chattooga': 'chattooga',
#  'clinch': 'clinch',
#  'coffee': 'coffee',
#  'tattnall': 'tattnall',
#  'twiggs': 'twiggs',
#  'valley': 'valley',
#  'champaign': 'champaign',
#  'jo daviess': 'jo daviess',
#  'rock island': 'rock island',
#  'stephenson': 'stephenson',
#  'ripley': 'ripley',
#  'cerro gordo': 'cerro gordo',
#  'kossuth': 'kossuth',
#  'poweshiek': 'poweshiek',
#  'sioux': 'sioux',
#  'tama': 'tama',
#  'woodbury': 'woodbury',
#  'mitchell': 'mitchell',
#  'breathitt': 'breathitt',
#  'hardin': 'hardin',
#  'jessamine': 'jessamine',
#  'acadia': 'amelia',
#  'cecil': 'cecil',
#  "st. mary's": "st. mary's",
#  'emmet': 'emmet',
#  'gladwin': 'gladwin',
#  'grand traverse': 'grand traverse',
#  'roscommon': 'roscommon',
#  'le sueur': 'le sueur',
#  'chickasaw': 'chickasaw',
#  'oktibbeha': 'oktibbeha',
#  'pontotoc': 'pontotoc',
#  'sunflower': 'sunflower',
#  'tate': 'tate',
#  'salem': 'salem',
#  'cortland': 'cortland',
#  'st. lawrence': 'st. lawrence',
#  'davie': 'davie',
#  'granville': 'granville',
#  'nash': 'nash',
#  'robeson': 'robeson',
#  'scotland': 'scotland',
#  'gallia': 'gallia',
#  'portage': 'portage',
#  'muskogee': 'muskogee',
#  'dauphin': 'dauphin',
#  'schuylkill': 'schuylkill',
#  'colleton': 'colleton',
#  'gibson': 'gibson',
#  'loudon': 'loudon',
#  'mcminn': 'mcminn',
#  'amherst': 'amherst',
#  'bedford': 'bedford',
#  'culpeper': 'culpeper',
#  'fluvanna': 'fluvanna',
#  'louisa': 'louisa',
#  'whitman': 'whitman',
#  'tallapoosa': 'tallapoosa',
#  'juneau city and borough': 'kodiak island borough',
#  'matanuska-susitna borough': 'matanuska-susitna borough',
#  'la plata': 'la plata',
#  'teller': 'teller',
#  'burke': 'burke',
#  'catoosa': 'catoosa',
#  'liberty': 'liberty',
#  'dubois': 'dubois',
#  'wapello': 'wapello',
#  'natchitoches': 'nacogdoches',
#  'st. martin': "st. mary's",
#  'garrett': 'garrett',
#  "queen anne's": "queen anne's",
#  'kalamazoo': 'kalamazoo',
#  'muskegon': 'muskegon',
#  'newaygo': 'newaygo',
#  'big stone': 'big stone',
#  'lac qui parle': 'lac qui parle',
#  'sherburne': 'sherburne',
#  'tallahatchie': 'tallahatchie',
#  'callaway': 'callaway',
#  'moniteau': 'moniteau',
#  'st. francois': 'st francois',
#  'taney': 'taney',
#  'chaves': 'chaves',
#  'cayuga': 'cayuga',
#  'oswego': 'oswego',
#  'alamance': 'alamance',
#  'vance': 'vance',
#  'walsh': 'walsh',
#  'sandusky': 'sandusky',
#  'hood river': 'hood river',
#  'cambria': 'cambria',
#  'georgetown': 'georgetown',
#  'codington': 'codington',
#  'hughes': 'hughes',
#  'lyman': 'lyman',
#  'pennington': 'pennington',
#  'iron': 'iron',
#  'danville city': 'danville city',
#  'rockbridge': 'rockbridge',
#  'autauga': 'autauga',
#  'conway': 'conway',
#  'crawford': 'crawford',
#  'cross': 'cross',
#  'hempstead': 'hempstead',
#  'hot spring': 'hot spring',
#  'stone': 'stone',
#  'white': 'white',
#  'woodruff': 'woodruff',
#  'calaveras': 'calaveras',
#  'merced': 'merced',
#  'mono': 'mono',
#  'delta': 'delta',
#  'huerfano': 'huerfano',
#  'ben hill': 'ben hill',
#  'bryan': 'bryan',
#  'colquitt': 'colquitt',
#  'crisp': 'crisp',
#  'irwin': 'irwin',
#  'macon': 'macon',
#  'meriwether': 'meriwether',
#  'stephens': 'stephens',
#  'telfair': 'telfair',
#  'bannock': 'bannock',
#  'cassia': 'cassia',
#  'grundy': 'grundy',
#  'dearborn': 'dearborn',
#  'decatur': 'decatur',
#  'ohio': 'ohio',
#  'porter': 'porter',
#  'starke': 'starke',
#  'warrick': 'warrick',
#  'buchanan': 'buchanan',
#  'cedar': 'cedar',
#  'doniphan': 'doniphan',
#  'pottawatomie': 'pottawatomie',
#  'woodson': 'woodson',
#  'mccracken': 'mccracken',
#  'menifee': 'menifee',
#  'muhlenberg': 'muhlenberg',
#  'vernon': 'vernon',
#  'waldo': 'waldo',
#  'hillsdale': 'hillsdale',
#  'isabella': 'isabella',
#  'kalkaska': 'kalkaska',
#  'lapeer': 'lapeer',
#  'manistee': 'manistee',
#  'choctaw': 'choctaw',
#  'noxubee': 'noxubee',
#  'cape girardeau': 'cape girardeau',
#  'pemiscot': 'pemiscot',
#  'saunders': 'saunders',
#  'cibola': 'cibola',
#  'curry': 'curry',
#  'chemung': 'chemung',
#  'transylvania': 'transylvania',
#  'highland': 'highland',
#  'mayes': 'mayes',
#  'wagoner': 'wagoner',
#  'clatsop': 'clatsop',
#  'armstrong': 'armstrong',
#  'clearfield': 'clearfield',
#  'juniata': 'juniata',
#  'brookings': 'brookings',
#  'overton': 'overton',
#  'weakley': 'weakley',
#  'comal': 'comal',
#  'falls': 'falls',
#  'grayson': 'grayson',
#  'hidalgo': 'hidalgo',
#  'nueces': 'nueces',
#  'parker': 'parker',
#  'victoria': 'victoria',
#  'caledonia': 'caledonia',
#  'chesapeake city': 'chesapeake city',
#  'halifax': 'halifax',
#  'preston': 'preston',
#  'sweetwater': 'sweetwater',
#  'chilton': 'chilton',
#  'colbert': 'colbert',
#  'etowah': 'etowah',
#  'russell': 'russell',
#  'wilcox': 'wilcox',
#  'drew': 'drew',
#  'inyo': 'inyo',
#  'sutter': 'sutter',
#  'otero': 'otero',
#  'gadsden': 'gadsden',
#  'long': 'long',
#  'taylor': 'taylor',
#  'thomas': 'thomas',
#  'ware': 'ware',
#  'wilkes': 'wilkes',
#  'idaho': 'idaho',
#  'nez perce': 'nez perce',
#  'payette': 'payette',
#  'rush': 'rush',
#  'neosho': 'neosho',
#  'shawnee': 'shawnee',
#  'laurel': 'laurel',
#  'mccreary': 'mccreary',
#  'jefferson davis': 'jefferson davis',
#  'morehouse': 'montrose',
#  'winn': 'linn',
#  'dukes': 'dukes',
#  'iosco': 'iosco',
#  'lenawee': 'lenawee',
#  'luce': 'luce',
#  'marquette': 'marquette',
#  'sanilac': 'sanilac',
#  'goodhue': 'goodhue',
#  'winona': 'winona',
#  'amite': 'amite',
#  'prentiss': 'prentiss',
#  'cooper': 'cooper',
#  'mcdonald': 'mcdonald',
#  'platte': 'platte',
#  'ralls': 'ralls',
#  'hill': 'hill',
#  'eddy': 'eddy',
#  'rio arriba': 'rio arriba',
#  'chautauqua': 'chautauqua',
#  'bertie': 'bertie',
#  'caldwell': 'caldwell',
#  'duplin': 'duplin',
#  'hertford': 'hertford',
#  'lenoir': 'lenoir',
#  'mcdowell': 'mcdowell',
#  'foster': 'foster',
#  'pickaway': 'pickaway',
#  'seneca': 'seneca',
#  'carter': 'carter',
#  'creek': 'creek',
#  'osage': 'osage',
#  'lycoming': 'lycoming',
#  'newport': 'newport',
#  'providence': 'providence',
#  'williamsburg': 'williamsburg',
#  'meade': 'meade',
#  'hawkins': 'hawkins',
#  ...}

# %% [markdown]
# ### References
# * https://stackoverflow.com/questions/45545110/how-do-you-parallelize-apply-on-pandas-dataframes-making-use-of-all-cores-on-o
# * https://stackoverflow.com/questions/5442910/python-multiprocessing-pool-map-for-multiple-arguments
# * https://stackoverflow.com/questions/26784164/pandas-multiprocessing-apply
# * https://stackoverflow.com/questions/25510482/python-pandas-multiprocessing-apply
# * https://docs.dask.org/en/latest/dataframe-api.html#dask.dataframe.DataFrame.map_partitions

# %% [markdown]
# ### Ideas for combination of distance metrics
#  * https://pypi.org/project/python-Levenshtein/0.12.0/
#  * https://rawgit.com/ztane/python-Levenshtein/master/docs/Levenshtein.html#Levenshtein-distance
#  * https://towardsdatascience.com/fuzzy-string-matching-in-python-68f240d910fe

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
dist1 = Levenshtein.distance('Cook', 'Cook County')
ratio_1 = fuzz.ratio('Cook', 'Cook County')
print('distance: ', dist1, ' ratio: ', ratio_1)
print('Similarity score: ', ratio_1 / dist1)
# Out:
# distance:  7  ratio:  53
# Similarity score:  7.571428571428571

# %%
dist2 = Levenshtein.distance('Cook', 'Carolina')
ratio_2 = fuzz.ratio('Cook', 'Carolina')
print('distance: ', dist2, ' ratio: ', ratio_2)
print('Similarity score: ', ratio_2 / dist2)
# Out:
# distance:  6  ratio:  33
# Similarity score:  5.5

# %%
dist2 = Levenshtein.distance('Cook', 'Cooke')
ratio_2 = fuzz.ratio('Cook', 'Cooke')
print('distance: ', dist2, ' ratio: ', ratio_2)
print('Similarity score: ', ratio_2 / dist2)
# Out:
# distance:  1  ratio:  89
# Similarity score:  89.0

# %% [markdown]
# # Try import

# %%
sys.path.append('/Users/nathanieldake/development/unsupervised/notebooks/utils/join_chain')

# %%
import jc_support

# %%
df.head(1)
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0

# %%
df_zip_map.head(1)
# Out:
#    zip    type primary_city acceptable_cities   unacceptable_cities state  \
# 0  501  UNIQUE   Holtsville               NaN  I R S Service Center    NY
#
#            county          timezone area_codes  latitude  longitude  \
# 0  Suffolk County  America/New_York        631     40.81     -73.04
#
#   world_region country  decommissioned  estimated_population notes
# 0          NaN      US               0                   384   NaN

# %%
df_merged = jc_support.JoinChainSupport.fuzzy_join(
    df,
    df_zip_map,
    left_on=[
        {'col': 'county', 'preprocess_func': preprocess_county},
        {'col': 'state', 'preprocess_func': preprocess_state}
    ],
    right_on=[
        {'col': 'county', 'preprocess_func': preprocess_county},
        {'col': 'state', 'preprocess_func': lower}
    ],
    fuzzy_distance_func=levenshtein_distance,
    implementation='dask',
    num_workers=10
)

# %%
df_merged.shape
# Out:
# (943323, 24)

# %%
df_merged.head()
# Out:
#          date   county_x     state_x     fips  cases  deaths  \
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-21  Snohomish  Washington  53061.0      1       0
# 2  2020-01-21  Snohomish  Washington  53061.0      1       0
# 3  2020-01-21  Snohomish  Washington  53061.0      1       0
# 4  2020-01-21  Snohomish  Washington  53061.0      1       0
#
#   preprocessed_county_state join_county_state    zip      type  ...  \
# 0             snohomish_wa_     snohomish_wa_  98012  STANDARD  ...
# 1             snohomish_wa_     snohomish_wa_  98020  STANDARD  ...
# 2             snohomish_wa_     snohomish_wa_  98021  STANDARD  ...
# 3             snohomish_wa_     snohomish_wa_  98026  STANDARD  ...
# 4             snohomish_wa_     snohomish_wa_  98036  STANDARD  ...
#
#            county_y             timezone   area_codes latitude longitude  \
# 0  Snohomish County  America/Los_Angeles      425,206    47.84   -122.19
# 1  Snohomish County  America/Los_Angeles      206,425    47.80   -122.37
# 2  Snohomish County  America/Los_Angeles      425,206    47.79   -122.20
# 3  Snohomish County  America/Los_Angeles      425,206    47.83   -122.32
# 4  Snohomish County  America/Los_Angeles  425,360,206    47.80   -122.28
#
#   world_region country  decommissioned  estimated_population notes
# 0          NaN      US               0                 45281   NaN
# 1          NaN      US               0                 17301   NaN
# 2          NaN      US               0                 22499   NaN
# 3          NaN      US               0                 30510   NaN
# 4          NaN      US               0                 29598   NaN
#
# [5 rows x 24 columns]

# %%
def preprocess_county(county_col):
    """Lower and remove County from end"""
    return county_col.str.lower().str.replace(' county', '')

def preprocess_state(state_col):
    df_state_map = pd.read_csv(
        'https://worldpopulationreview.com/static/states/abbr-name.csv',
        header=None
    ).rename(columns={0: 'abbreviation', 1: 'full'})
    df_state_map = df_state_map[['full', 'abbreviation']]

    df_state_map = df_state_map.assign(
        full=df_state_map.full.str.lower(),
        abbreviation=df_state_map.abbreviation.str.lower()
    )
    
    df_state_dict_map = dict(sorted(df_state_map.values.tolist(), reverse=True))
    state_col = state_col.str.lower().map(df_state_dict_map)

    return state_col


def lower(col):
    return col.str.lower()
